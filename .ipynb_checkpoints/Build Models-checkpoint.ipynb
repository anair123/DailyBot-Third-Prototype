# %% [markdown]
# # Libraries

# %%
import json
import nltk
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer
import numpy as np
import random
import pickle
from textblob import TextBlob
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from textblob import TextBlob
import os
from autocorrect import Speller
from spellchecker import SpellChecker


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Load JSON Files

# %%
# English Data
data_en = json.loads(open('data_en.json').read())

# Spanish Data
data_es = json.loads(open('data_es.json').read())

# %% [markdown]
# ## Natural Language Processing

# %%
intents_en = data_en['interactionModel']['languageModel']

intents_es = data_es['interactionModel']['languageModel']

# %%
# Create a list of tuples that assigns a list of words to an intent in English
words_en = []
labels_en = []
documents_en = []
punc_en = ['?', '!', ',', '.']

for intent in intents_en['intent']: 
    for sample in intent['samples']:
        word_list_en = nltk.word_tokenize(sample)
        words_en.extend(word_list_en)
        documents_en.append((word_list_en, intent['name']))
        if intent['name'] not in labels_en:
            labels_en.append(intent['name'])

# %%
# Create a list of tuples that assigns a list of words to an intent in Spanish
words_es = []
labels_es = []
documents_es = []
punc_es = ['?', '!', ',', '.']

for intent in intents_es['intent']: 
    for sample in intent['samples']:
        word_list_es = nltk.word_tokenize(sample)
        words_es.extend(word_list_es)
        documents_es.append((word_list_es, intent['name']))
        if intent['name'] not in labels_es:
            labels_es.append(intent['name'])

# %% [markdown]
# ## Bag of Words

# %%
# import NLP library
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()

# %%
# turn words to lower case and to base form
words_en = [lem.lemmatize(word.lower()) for word in words_en if word not in punc_en]
words_es = [lem.lemmatize(word.lower()) for word in words_es if word not in punc_es]


# sort words and remove duplicates in English
words_en = sorted(set(words_en))
labels_en = sorted(set(labels_en))

# sort words and remove duplicates in Spanish
words_es = sorted(set(words_es))
labels_es = sorted(set(labels_es))

# %% [markdown]
# ## Preprocessing input and output data

# %%
# create training and output arrays in English
training_en = []
output_empty_en = [0] * len(labels_en)
for document in documents_en:
    bag_en = []
    word_patterns_en = document[0]
    word_patterns_en = [lem.lemmatize(word.lower()) for word in word_patterns_en]
    for word in words_en:
        if word in word_patterns_en:
            bag_en.append(1)
        else:
            bag_en.append(0)
            
    # copy output list
    output_en = list(output_empty_en)
    output_en[labels_en.index(document[1])] = 1
    training_en.append([bag_en, output_en])

# %%
# create training and output arrays in Spanish
training_es = []
output_empty_es = [0] * len(labels_es)
for document in documents_es:
    bag_es = []
    word_patterns_es = document[0]
    word_patterns_es = [lem.lemmatize(word.lower()) for word in word_patterns_es]
    for word in words_es:
        if word in word_patterns_es:
            bag_es.append(1)
        else:
            bag_es.append(0)
            
    # copy output list
    output_es = list(output_empty_es)
    output_es[labels_es.index(document[1])] = 1
    training_es.append([bag_es, output_es])

# %%
# randomizing the order of the training data in English
random.shuffle(training_en)
training_en = np.array(training_en)

train_x_en = list(training_en[:,0])
train_y_en = list(training_en[:,1])

# randomizing the order of the training data in Spanish
random.shuffle(training_es)
training_es = np.array(training_es)

train_x_es = list(training_es[:,0])
train_y_es = list(training_es[:,1])
# Out:
# C:\Users\aashi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\aashi\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Build Model

# %%
def model_en():
    model = Sequential()
    model.add(Dense(128, input_shape=(len(train_x_en[0]),), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(train_y_en[0]), activation='softmax'))
    return model


def model_es():
    model = Sequential()
    model.add(Dense(128, input_shape=(len(train_x_es[0]),), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(train_y_es[0]), activation='softmax'))
    return model

# %% [markdown]
# ### Train English Model

# %%
model_en = model_en()

optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_en.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
checkpoint_en = ModelCheckpoint(filepath='model_en.h5', monitor='acc')
model_en.fit(np.array(train_x_en), np.array(train_y_en), epochs=500, batch_size=5, verbose=1, callbacks=[checkpoint_en])
# Out:
# Epoch 1/500
# 91/91 [==============================] - 0s 5ms/sample - loss: 3.1171 - acc: 0.0440
# Epoch 2/500
# 91/91 [==============================] - 0s 373us/sample - loss: 3.0713 - acc: 0.0659
# Epoch 3/500
# 91/91 [==============================] - 0s 329us/sample - loss: 3.0120 - acc: 0.0879
# Epoch 4/500
# 91/91 [==============================] - 0s 296us/sample - loss: 2.9226 - acc: 0.0989
# Epoch 5/500
# 91/91 [==============================] - 0s 285us/sample - loss: 2.8562 - acc: 0.1868
# Epoch 6/500
# 91/91 [==============================] - 0s 252us/sample - loss: 2.7753 - acc: 0.1648
# Epoch 7/500
# 91/91 [==============================] - 0s 274us/sample - loss: 2.6584 - acc: 0.2418
# Epoch 8/500
# 91/91 [==============================] - 0s 274us/sample - loss: 2.5488 - acc: 0.2418
# Epoch 9/500
# 91/91 [==============================] - 0s 318us/sample - loss: 2.5045 - acc: 0.2637
# Epoch 10/500
# 91/91 [==============================] - 0s 285us/sample - loss: 2.4175 - acc: 0.3297
# Epoch 11/500
# 91/91 [==============================] - 0s 274us/sample - loss: 2.1953 - acc: 0.3846
# Epoch 12/500
# 91/91 [==============================] - 0s 263us/sample - loss: 2.1540 - acc: 0.3516
# Epoch 13/500
# 91/91 [==============================] - 0s 285us/sample - loss: 1.9444 - acc: 0.4725
# Epoch 14/500
# 91/91 [==============================] - 0s 263us/sample - loss: 1.9128 - acc: 0.4615
# Epoch 15/500
# 91/91 [==============================] - 0s 307us/sample - loss: 1.6157 - acc: 0.5055
# Epoch 16/500
# 91/91 [==============================] - 0s 285us/sample - loss: 1.7540 - acc: 0.4835
# Epoch 17/500
# 91/91 [==============================] - 0s 274us/sample - loss: 1.6210 - acc: 0.5385
# Epoch 18/500
# 91/91 [==============================] - 0s 263us/sample - loss: 1.5407 - acc: 0.6154
# Epoch 19/500
# 91/91 [==============================] - 0s 285us/sample - loss: 1.4100 - acc: 0.6374
# Epoch 20/500
# 91/91 [==============================] - 0s 263us/sample - loss: 1.2480 - acc: 0.7033
# Epoch 21/500
# 91/91 [==============================] - 0s 307us/sample - loss: 1.3653 - acc: 0.6264
# Epoch 22/500
# 91/91 [==============================] - 0s 285us/sample - loss: 1.1451 - acc: 0.7033
# Epoch 23/500
# 91/91 [==============================] - 0s 263us/sample - loss: 1.1583 - acc: 0.6593
# Epoch 24/500
# 91/91 [==============================] - 0s 307us/sample - loss: 1.0826 - acc: 0.6813
# Epoch 25/500
# 91/91 [==============================] - 0s 285us/sample - loss: 1.0835 - acc: 0.6593
# Epoch 26/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.8893 - acc: 0.7692
# Epoch 27/500
# 91/91 [==============================] - 0s 296us/sample - loss: 1.0033 - acc: 0.7033
# Epoch 28/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.8579 - acc: 0.7363
# Epoch 29/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.8166 - acc: 0.8242
# Epoch 30/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.7296 - acc: 0.7912
# Epoch 31/500
# 91/91 [==============================] - 0s 416us/sample - loss: 0.6967 - acc: 0.8352
# Epoch 32/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.6819 - acc: 0.8132
# Epoch 33/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.6387 - acc: 0.8462
# Epoch 34/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.4999 - acc: 0.8571
# Epoch 35/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.6067 - acc: 0.8132
# Epoch 36/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.5450 - acc: 0.8352
# Epoch 37/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.6712 - acc: 0.8022
# Epoch 38/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.6433 - acc: 0.7802
# Epoch 39/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.5331 - acc: 0.8571
# Epoch 40/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.5325 - acc: 0.8571
# Epoch 41/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.5363 - acc: 0.8022
# Epoch 42/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.3524 - acc: 0.9231
# Epoch 43/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.3405 - acc: 0.9011
# Epoch 44/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.3615 - acc: 0.9011
# Epoch 45/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.3742 - acc: 0.9011
# Epoch 46/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.4167 - acc: 0.8462
# Epoch 47/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.4270 - acc: 0.9231
# Epoch 48/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.2589 - acc: 0.9341
# Epoch 49/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.4282 - acc: 0.8791
# Epoch 50/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.3835 - acc: 0.8901
# Epoch 51/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.2245 - acc: 0.9670
# Epoch 52/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.3282 - acc: 0.9231
# Epoch 53/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.2384 - acc: 0.9341
# Epoch 54/500
# 91/91 [==============================] - 0s 384us/sample - loss: 0.2833 - acc: 0.9451
# Epoch 55/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1873 - acc: 0.9451
# Epoch 56/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1779 - acc: 0.9780
# Epoch 57/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.3739 - acc: 0.8791
# Epoch 58/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2046 - acc: 0.9560
# Epoch 59/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2148 - acc: 0.9341
# Epoch 60/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.2688 - acc: 0.9231
# Epoch 61/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2264 - acc: 0.9231
# Epoch 62/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1921 - acc: 0.9780
# Epoch 63/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2966 - acc: 0.9341
# Epoch 64/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2275 - acc: 0.9451
# Epoch 65/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.2404 - acc: 0.9341
# Epoch 66/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.2952 - acc: 0.8901
# Epoch 67/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.3381 - acc: 0.8571
# Epoch 68/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.3322 - acc: 0.9011
# Epoch 69/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.3254 - acc: 0.8901
# Epoch 70/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.2547 - acc: 0.9341
# Epoch 71/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1480 - acc: 0.9670
# Epoch 72/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1857 - acc: 0.9451
# Epoch 73/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1732 - acc: 0.9780
# Epoch 74/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1548 - acc: 0.9780
# Epoch 75/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.2306 - acc: 0.9560
# Epoch 76/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1021 - acc: 1.0000
# Epoch 77/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.2260 - acc: 0.9231
# Epoch 78/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1098 - acc: 0.9890
# Epoch 79/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.2441 - acc: 0.9231
# Epoch 80/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2108 - acc: 0.9121
# Epoch 81/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2202 - acc: 0.9231
# Epoch 82/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1267 - acc: 0.9890
# Epoch 83/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1585 - acc: 0.9670
# Epoch 84/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1598 - acc: 0.9780
# Epoch 85/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2225 - acc: 0.9341
# Epoch 86/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1980 - acc: 0.9560
# Epoch 87/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2510 - acc: 0.9011
# Epoch 88/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1338 - acc: 0.9670
# Epoch 89/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1939 - acc: 0.9560
# Epoch 90/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1259 - acc: 0.9560
# Epoch 91/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1920 - acc: 0.9560
# Epoch 92/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1473 - acc: 0.9780
# Epoch 93/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0953 - acc: 0.9780
# Epoch 94/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1006 - acc: 0.9670
# Epoch 95/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1626 - acc: 0.9341
# Epoch 96/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1415 - acc: 0.9670
# Epoch 97/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1526 - acc: 0.9670
# Epoch 98/500
# 91/91 [==============================] - 0s 241us/sample - loss: 0.1910 - acc: 0.9451
# Epoch 99/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0854 - acc: 1.0000
# Epoch 100/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.2121 - acc: 0.9231
# Epoch 101/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1416 - acc: 0.9451
# Epoch 102/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1768 - acc: 0.9451
# Epoch 103/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1533 - acc: 0.9451
# Epoch 104/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1164 - acc: 0.9670
# Epoch 105/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1335 - acc: 0.9451
# Epoch 106/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1036 - acc: 0.9780
# Epoch 107/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0985 - acc: 0.9780
# Epoch 108/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1379 - acc: 0.9451
# Epoch 109/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1232 - acc: 0.9670
# Epoch 110/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0955 - acc: 0.9780
# Epoch 111/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0738 - acc: 1.0000
# Epoch 112/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0874 - acc: 0.9780
# Epoch 113/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1076 - acc: 0.9560
# Epoch 114/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0655 - acc: 1.0000
# Epoch 115/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.1485 - acc: 0.9451
# Epoch 116/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1117 - acc: 0.9670
# Epoch 117/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.1036 - acc: 0.9670
# Epoch 118/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.2159 - acc: 0.9560
# Epoch 119/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1477 - acc: 0.9341
# Epoch 120/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0870 - acc: 0.9890
# Epoch 121/500
# 91/91 [==============================] - 0s 416us/sample - loss: 0.1109 - acc: 0.9451
# Epoch 122/500
# 91/91 [==============================] - 0s 548us/sample - loss: 0.0975 - acc: 0.9780
# Epoch 123/500
# 91/91 [==============================] - 0s 427us/sample - loss: 0.0491 - acc: 1.0000
# Epoch 124/500
# 91/91 [==============================] - 0s 395us/sample - loss: 0.1978 - acc: 0.9341
# Epoch 125/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.1046 - acc: 0.9670
# Epoch 126/500
# 91/91 [==============================] - 0s 416us/sample - loss: 0.1194 - acc: 0.9780
# Epoch 127/500
# 91/91 [==============================] - 0s 384us/sample - loss: 0.1177 - acc: 0.9780
# Epoch 128/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.1191 - acc: 0.9890
# Epoch 129/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.0868 - acc: 0.9780
# Epoch 130/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.1100 - acc: 0.9780
# Epoch 131/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0794 - acc: 0.9780
# Epoch 132/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0840 - acc: 0.9780
# Epoch 133/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0921 - acc: 0.9780
# Epoch 134/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.1066 - acc: 0.9890
# Epoch 135/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.1225 - acc: 0.9560
# Epoch 136/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0826 - acc: 0.9890
# Epoch 137/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.1332 - acc: 0.9670
# Epoch 138/500
# 91/91 [==============================] - 0s 427us/sample - loss: 0.1022 - acc: 0.9670
# Epoch 139/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.1105 - acc: 0.9780
# Epoch 140/500
# 91/91 [==============================] - 0s 438us/sample - loss: 0.0917 - acc: 0.9780
# Epoch 141/500
# 91/91 [==============================] - 0s 482us/sample - loss: 0.0554 - acc: 1.0000
# Epoch 142/500
# 91/91 [==============================] - 0s 395us/sample - loss: 0.0823 - acc: 0.9890
# Epoch 143/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.0540 - acc: 1.0000
# Epoch 144/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0996 - acc: 0.9670
# Epoch 145/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0589 - acc: 0.9890
# Epoch 146/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.1126 - acc: 0.9670
# Epoch 147/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.1081 - acc: 0.9670
# Epoch 148/500
# 91/91 [==============================] - 0s 460us/sample - loss: 0.2191 - acc: 0.9451
# Epoch 149/500
# 91/91 [==============================] - 0s 362us/sample - loss: 0.1224 - acc: 0.9780
# Epoch 150/500
# 91/91 [==============================] - 0s 373us/sample - loss: 0.1226 - acc: 0.9670
# Epoch 151/500
# 91/91 [==============================] - 0s 395us/sample - loss: 0.1029 - acc: 0.9670
# Epoch 152/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.1174 - acc: 0.9560
# Epoch 153/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0844 - acc: 0.9890
# Epoch 154/500
# 91/91 [==============================] - 0s 416us/sample - loss: 0.1334 - acc: 0.9560
# Epoch 155/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.1392 - acc: 0.9670
# Epoch 156/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0657 - acc: 0.9780
# Epoch 157/500
# 91/91 [==============================] - 0s 302us/sample - loss: 0.1063 - acc: 0.9890
# Epoch 158/500
# 91/91 [==============================] - 0s 301us/sample - loss: 0.1127 - acc: 0.9670
# Epoch 159/500
# 91/91 [==============================] - 0s 301us/sample - loss: 0.2252 - acc: 0.9121
# Epoch 160/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0462 - acc: 1.0000
# Epoch 161/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.1312 - acc: 0.9560
# Epoch 162/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0598 - acc: 0.9890
# Epoch 163/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.0660 - acc: 0.9780
# Epoch 164/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0953 - acc: 0.9780
# Epoch 165/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0735 - acc: 0.9780
# Epoch 166/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0547 - acc: 0.9890
# Epoch 167/500
# 91/91 [==============================] - 0s 384us/sample - loss: 0.0355 - acc: 0.9890
# Epoch 168/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0487 - acc: 0.9780
# Epoch 169/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0641 - acc: 0.9780
# Epoch 170/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0529 - acc: 0.9890
# Epoch 171/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0611 - acc: 0.9780
# Epoch 172/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0604 - acc: 0.9780
# Epoch 173/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0543 - acc: 0.9890
# Epoch 174/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0404 - acc: 0.9890
# Epoch 175/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0536 - acc: 0.9890
# Epoch 176/500
# 91/91 [==============================] - 0s 416us/sample - loss: 0.0485 - acc: 0.9890
# Epoch 177/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0772 - acc: 0.9780
# Epoch 178/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0411 - acc: 1.0000
# Epoch 179/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0410 - acc: 0.9890
# Epoch 180/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0287 - acc: 1.0000
# Epoch 181/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0628 - acc: 0.9670
# Epoch 182/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0811 - acc: 0.9780
# Epoch 183/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0981 - acc: 0.9670
# Epoch 184/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0483 - acc: 0.9890
# Epoch 185/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0542 - acc: 0.9890
# Epoch 186/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0838 - acc: 0.9670
# Epoch 187/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0592 - acc: 0.9780
# Epoch 188/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0592 - acc: 1.0000
# Epoch 189/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0420 - acc: 1.0000
# Epoch 190/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.1453 - acc: 0.9780
# Epoch 191/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0493 - acc: 0.9890
# Epoch 192/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0569 - acc: 0.9890
# Epoch 193/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0327 - acc: 1.0000
# Epoch 194/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0767 - acc: 0.9780
# Epoch 195/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0209 - acc: 0.9890
# Epoch 196/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0481 - acc: 0.9890
# Epoch 197/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1585 - acc: 0.9560
# Epoch 198/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0829 - acc: 0.9670
# Epoch 199/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0295 - acc: 1.0000
# Epoch 200/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0187 - acc: 1.0000
# Epoch 201/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0335 - acc: 0.9890
# Epoch 202/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0582 - acc: 0.9670
# Epoch 203/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0787 - acc: 0.9780
# Epoch 204/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0642 - acc: 0.9780
# Epoch 205/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0506 - acc: 0.9890
# Epoch 206/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0506 - acc: 0.9890
# Epoch 207/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0509 - acc: 1.0000
# Epoch 208/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0244 - acc: 1.0000
# Epoch 209/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0506 - acc: 0.9890
# Epoch 210/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0549 - acc: 0.9780
# Epoch 211/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0374 - acc: 0.9780
# Epoch 212/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0378 - acc: 0.9780
# Epoch 213/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0450 - acc: 0.9890
# Epoch 214/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0702 - acc: 0.9780
# Epoch 215/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0556 - acc: 0.9890
# Epoch 216/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0303 - acc: 1.0000
# Epoch 217/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0302 - acc: 0.9890
# Epoch 218/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0225 - acc: 1.0000
# Epoch 219/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0693 - acc: 0.9780
# Epoch 220/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0581 - acc: 0.9890
# Epoch 221/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0569 - acc: 0.9890
# Epoch 222/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0295 - acc: 1.0000
# Epoch 223/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0380 - acc: 1.0000
# Epoch 224/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0469 - acc: 0.9890
# Epoch 225/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1189 - acc: 0.9560
# Epoch 226/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.1017 - acc: 0.9670
# Epoch 227/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1190 - acc: 0.9560
# Epoch 228/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0701 - acc: 0.9670
# Epoch 229/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0750 - acc: 0.9780
# Epoch 230/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0570 - acc: 0.9890
# Epoch 231/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0389 - acc: 0.9780
# Epoch 232/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0175 - acc: 1.0000
# Epoch 233/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0471 - acc: 0.9890
# Epoch 234/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0607 - acc: 0.9890
# Epoch 235/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0795 - acc: 0.9780
# Epoch 236/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0774 - acc: 0.9780
# Epoch 237/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0974 - acc: 0.9560
# Epoch 238/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0443 - acc: 0.9890
# Epoch 239/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1386 - acc: 0.9341
# Epoch 240/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0350 - acc: 0.9890
# Epoch 241/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0346 - acc: 0.9890
# Epoch 242/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0387 - acc: 0.9890
# Epoch 243/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0556 - acc: 0.9780
# Epoch 244/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0957 - acc: 0.9560
# Epoch 245/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0253 - acc: 1.0000
# Epoch 246/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0316 - acc: 1.0000
# Epoch 247/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0384 - acc: 0.9780
# Epoch 248/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0568 - acc: 0.9890
# Epoch 249/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0954 - acc: 0.9451
# Epoch 250/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1005 - acc: 0.9780
# Epoch 251/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0672 - acc: 0.9780
# Epoch 252/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1236 - acc: 0.9560
# Epoch 253/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1212 - acc: 0.9560
# Epoch 254/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0531 - acc: 0.9670
# Epoch 255/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0567 - acc: 0.9890
# Epoch 256/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0336 - acc: 0.9890
# Epoch 257/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0259 - acc: 0.9890
# Epoch 258/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0408 - acc: 0.9890
# Epoch 259/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0183 - acc: 1.0000
# Epoch 260/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0372 - acc: 1.0000
# Epoch 261/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0250 - acc: 1.0000
# Epoch 262/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0120 - acc: 1.0000
# Epoch 263/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0115 - acc: 1.0000
# Epoch 264/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.1282 - acc: 0.9670
# Epoch 265/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0412 - acc: 0.9890
# Epoch 266/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0291 - acc: 0.9780
# Epoch 267/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0427 - acc: 1.0000
# Epoch 268/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0324 - acc: 0.9890
# Epoch 269/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0380 - acc: 1.0000
# Epoch 270/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0216 - acc: 1.0000
# Epoch 271/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0196 - acc: 1.0000
# Epoch 272/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0070 - acc: 1.0000
# Epoch 273/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0346 - acc: 0.9890
# Epoch 274/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0759 - acc: 0.9780
# Epoch 275/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1178 - acc: 0.9780
# Epoch 276/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0513 - acc: 0.9780
# Epoch 277/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.1838 - acc: 0.9560
# Epoch 278/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.2731 - acc: 0.9231
# Epoch 279/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0802 - acc: 0.9780
# Epoch 280/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.1817 - acc: 0.9231
# Epoch 281/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0798 - acc: 0.9560
# Epoch 282/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0769 - acc: 0.9560
# Epoch 283/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0566 - acc: 0.9890
# Epoch 284/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0695 - acc: 0.9780
# Epoch 285/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0351 - acc: 1.0000
# Epoch 286/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0539 - acc: 0.9780
# Epoch 287/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0724 - acc: 0.9670
# Epoch 288/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1169 - acc: 0.9560
# Epoch 289/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0424 - acc: 0.9890
# Epoch 290/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0251 - acc: 0.9890
# Epoch 291/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0691 - acc: 0.9780
# Epoch 292/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0677 - acc: 0.9670
# Epoch 293/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0440 - acc: 0.9780
# Epoch 294/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0327 - acc: 1.0000
# Epoch 295/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0783 - acc: 0.9780
# Epoch 296/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.1015 - acc: 0.9670
# Epoch 297/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0272 - acc: 0.9890
# Epoch 298/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0546 - acc: 0.9780
# Epoch 299/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0256 - acc: 1.0000
# Epoch 300/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0466 - acc: 0.9890
# Epoch 301/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0965 - acc: 0.9670
# Epoch 302/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0340 - acc: 1.0000
# Epoch 303/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0508 - acc: 0.9670
# Epoch 304/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0471 - acc: 0.9890
# Epoch 305/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0162 - acc: 0.9890
# Epoch 306/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0537 - acc: 0.9780
# Epoch 307/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1108 - acc: 0.9780
# Epoch 308/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0335 - acc: 0.9890
# Epoch 309/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0274 - acc: 0.9890
# Epoch 310/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0713 - acc: 0.9780
# Epoch 311/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0714 - acc: 0.9890
# Epoch 312/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0496 - acc: 0.9890
# Epoch 313/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0468 - acc: 0.9890
# Epoch 314/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0164 - acc: 1.0000
# Epoch 315/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0874 - acc: 0.9670
# Epoch 316/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0671 - acc: 0.9780
# Epoch 317/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0261 - acc: 0.9890
# Epoch 318/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0772 - acc: 0.9780
# Epoch 319/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0312 - acc: 1.0000
# Epoch 320/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0568 - acc: 0.9780
# Epoch 321/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0455 - acc: 0.9890
# Epoch 322/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0715 - acc: 0.9780
# Epoch 323/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0462 - acc: 0.9890
# Epoch 324/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0486 - acc: 1.0000
# Epoch 325/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0522 - acc: 0.9890
# Epoch 326/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0412 - acc: 0.9890
# Epoch 327/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0654 - acc: 0.9780
# Epoch 328/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0277 - acc: 0.9890
# Epoch 329/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0848 - acc: 0.9670
# Epoch 330/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0685 - acc: 0.9780
# Epoch 331/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0385 - acc: 0.9890
# Epoch 332/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0711 - acc: 0.9780
# Epoch 333/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0408 - acc: 0.9890
# Epoch 334/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0273 - acc: 1.0000
# Epoch 335/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0778 - acc: 0.9670
# Epoch 336/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0740 - acc: 0.9670
# Epoch 337/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0266 - acc: 0.9890
# Epoch 338/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0468 - acc: 0.9780
# Epoch 339/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.0599 - acc: 1.0000
# Epoch 340/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0607 - acc: 0.9890
# Epoch 341/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0301 - acc: 0.9890
# Epoch 342/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0418 - acc: 0.9890
# Epoch 343/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0577 - acc: 0.9890
# Epoch 344/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0316 - acc: 0.9890
# Epoch 345/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0301 - acc: 0.9890
# Epoch 346/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0745 - acc: 0.9890
# Epoch 347/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0330 - acc: 0.9890
# Epoch 348/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0833 - acc: 0.9670
# Epoch 349/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0288 - acc: 1.0000
# Epoch 350/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0369 - acc: 0.9890
# Epoch 351/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0066 - acc: 1.0000
# Epoch 352/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0316 - acc: 0.9890
# Epoch 353/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0277 - acc: 1.0000
# Epoch 354/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0255 - acc: 1.0000
# Epoch 355/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0588 - acc: 0.9780
# Epoch 356/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0199 - acc: 1.0000
# Epoch 357/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1690 - acc: 0.9670
# Epoch 358/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0244 - acc: 0.9890
# Epoch 359/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0548 - acc: 0.9890
# Epoch 360/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0519 - acc: 0.9780
# Epoch 361/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0599 - acc: 0.9780
# Epoch 362/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.1207 - acc: 0.9560
# Epoch 363/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0361 - acc: 0.9890
# Epoch 364/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0272 - acc: 1.0000
# Epoch 365/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0381 - acc: 0.9890
# Epoch 366/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0775 - acc: 0.9780
# Epoch 367/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0787 - acc: 0.9780
# Epoch 368/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0415 - acc: 0.9890
# Epoch 369/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0086 - acc: 1.0000
# Epoch 370/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0410 - acc: 0.9780
# Epoch 371/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0402 - acc: 0.9780
# Epoch 372/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0236 - acc: 0.9890
# Epoch 373/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0188 - acc: 1.0000
# Epoch 374/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0303 - acc: 0.9890
# Epoch 375/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0119 - acc: 1.0000
# Epoch 376/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0359 - acc: 0.9890
# Epoch 377/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0101 - acc: 1.0000
# Epoch 378/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0325 - acc: 0.9890
# Epoch 379/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0313 - acc: 0.9780
# Epoch 380/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0957 - acc: 0.9780
# Epoch 381/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0160 - acc: 1.0000
# Epoch 382/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0180 - acc: 1.0000
# Epoch 383/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0137 - acc: 1.0000
# Epoch 384/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0604 - acc: 0.9780
# Epoch 385/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0406 - acc: 0.9780
# Epoch 386/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0323 - acc: 0.9780
# Epoch 387/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0569 - acc: 0.9780
# Epoch 388/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0253 - acc: 0.9890
# Epoch 389/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0313 - acc: 0.9780
# Epoch 390/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0906 - acc: 0.9780
# Epoch 391/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0227 - acc: 0.9890
# Epoch 392/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0401 - acc: 0.9890
# Epoch 393/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0434 - acc: 0.9890
# Epoch 394/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0687 - acc: 0.9780
# Epoch 395/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0274 - acc: 1.0000
# Epoch 396/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0446 - acc: 0.9890
# Epoch 397/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0194 - acc: 0.9890
# Epoch 398/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0319 - acc: 1.0000
# Epoch 399/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0503 - acc: 0.9890
# Epoch 400/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0075 - acc: 1.0000
# Epoch 401/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0268 - acc: 1.0000
# Epoch 402/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0556 - acc: 0.9780
# Epoch 403/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0489 - acc: 0.9780
# Epoch 404/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0347 - acc: 0.9780
# Epoch 405/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0221 - acc: 0.9890
# Epoch 406/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0497 - acc: 0.9780
# Epoch 407/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0246 - acc: 0.9890
# Epoch 408/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0277 - acc: 0.9890
# Epoch 409/500
# 91/91 [==============================] - 0s 340us/sample - loss: 0.0423 - acc: 0.9780
# Epoch 410/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0272 - acc: 0.9890
# Epoch 411/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0678 - acc: 0.9780
# Epoch 412/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0215 - acc: 0.9890
# Epoch 413/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0213 - acc: 1.0000
# Epoch 414/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.1151 - acc: 0.9780
# Epoch 415/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0029 - acc: 1.0000
# Epoch 416/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0075 - acc: 1.0000
# Epoch 417/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0576 - acc: 0.9670
# Epoch 418/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.1071 - acc: 0.9780
# Epoch 419/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0237 - acc: 0.9890
# Epoch 420/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0762 - acc: 0.9560
# Epoch 421/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0843 - acc: 0.9670
# Epoch 422/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1119 - acc: 0.9670
# Epoch 423/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0707 - acc: 0.9780
# Epoch 424/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0469 - acc: 0.9780
# Epoch 425/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0316 - acc: 0.9890
# Epoch 426/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0617 - acc: 0.9890
# Epoch 427/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0136 - acc: 1.0000
# Epoch 428/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0170 - acc: 1.0000
# Epoch 429/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0790 - acc: 0.9670
# Epoch 430/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.1428 - acc: 0.9560
# Epoch 431/500
# 91/91 [==============================] - 0s 351us/sample - loss: 0.0410 - acc: 0.9890
# Epoch 432/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0537 - acc: 0.9670
# Epoch 433/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0262 - acc: 1.0000
# Epoch 434/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0164 - acc: 1.0000
# Epoch 435/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0478 - acc: 1.0000
# Epoch 436/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0148 - acc: 1.0000
# Epoch 437/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0117 - acc: 1.0000
# Epoch 438/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0411 - acc: 0.9890
# Epoch 439/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0147 - acc: 0.9890
# Epoch 440/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0412 - acc: 0.9890
# Epoch 441/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0514 - acc: 0.9780
# Epoch 442/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0427 - acc: 0.9890
# Epoch 443/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0575 - acc: 0.9890
# Epoch 444/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0445 - acc: 0.9780
# Epoch 445/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0776 - acc: 0.9780
# Epoch 446/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0678 - acc: 0.9780
# Epoch 447/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0305 - acc: 0.9890
# Epoch 448/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0246 - acc: 1.0000
# Epoch 449/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0353 - acc: 0.9890
# Epoch 450/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0419 - acc: 0.9890
# Epoch 451/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0236 - acc: 1.0000
# Epoch 452/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0235 - acc: 1.0000
# Epoch 453/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0278 - acc: 0.9890
# Epoch 454/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0132 - acc: 1.0000
# Epoch 455/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0286 - acc: 0.9890
# Epoch 456/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0186 - acc: 1.0000
# Epoch 457/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0325 - acc: 1.0000
# Epoch 458/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0386 - acc: 0.9890
# Epoch 459/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0357 - acc: 0.9890
# Epoch 460/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0491 - acc: 0.9780
# Epoch 461/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0162 - acc: 0.9890
# Epoch 462/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0525 - acc: 0.9780
# Epoch 463/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0191 - acc: 1.0000
# Epoch 464/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0046 - acc: 1.0000
# Epoch 465/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0098 - acc: 1.0000
# Epoch 466/500
# 91/91 [==============================] - 0s 329us/sample - loss: 0.0203 - acc: 0.9890
# Epoch 467/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0378 - acc: 0.9890
# Epoch 468/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0301 - acc: 0.9890
# Epoch 469/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0313 - acc: 0.9890
# Epoch 470/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0269 - acc: 0.9890
# Epoch 471/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0539 - acc: 0.9890
# Epoch 472/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0826 - acc: 0.9670
# Epoch 473/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0592 - acc: 0.9780
# Epoch 474/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0179 - acc: 1.0000
# Epoch 475/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0128 - acc: 0.9890
# Epoch 476/500
# 91/91 [==============================] - 0s 307us/sample - loss: 0.0141 - acc: 1.0000
# Epoch 477/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0930 - acc: 0.9560
# Epoch 478/500
# 91/91 [==============================] - ETA: 0s - loss: 0.0028 - acc: 1.000 - 0s 274us/sample - loss: 0.0044 - acc: 1.0000
# Epoch 479/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0151 - acc: 1.0000
# Epoch 480/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0337 - acc: 0.9780
# Epoch 481/500
# 91/91 [==============================] - 0s 285us/sample - loss: 0.0562 - acc: 0.9780
# Epoch 482/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0677 - acc: 0.9780
# Epoch 483/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0472 - acc: 0.9890
# Epoch 484/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0582 - acc: 0.9890
# Epoch 485/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0509 - acc: 0.9890
# Epoch 486/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0175 - acc: 0.9890
# Epoch 487/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0158 - acc: 1.0000
# Epoch 488/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0289 - acc: 1.0000
# Epoch 489/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0488 - acc: 0.9780
# Epoch 490/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0647 - acc: 0.9780
# Epoch 491/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0135 - acc: 1.0000
# Epoch 492/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0260 - acc: 0.9890
# Epoch 493/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.1313 - acc: 0.9670
# Epoch 494/500
# 91/91 [==============================] - 0s 252us/sample - loss: 0.0379 - acc: 0.9890
# Epoch 495/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0138 - acc: 1.0000
# Epoch 496/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0481 - acc: 0.9780
# Epoch 497/500
# 91/91 [==============================] - 0s 296us/sample - loss: 0.0349 - acc: 0.9890
# Epoch 498/500
# 91/91 [==============================] - 0s 274us/sample - loss: 0.0333 - acc: 0.9890
# Epoch 499/500
# 91/91 [==============================] - 0s 263us/sample - loss: 0.0806 - acc: 0.9670
# Epoch 500/500
# 91/91 [==============================] - 0s 318us/sample - loss: 0.0461 - acc: 0.9890

# %% [markdown]
# ### Train Spanish Model

# %%
model_es = model_es()

optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_es.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
checkpoint_es = ModelCheckpoint(filepath='model_es.h5', monitor='acc')
model_es.fit(np.array(train_x_es), np.array(train_y_es), epochs=500, batch_size=5, verbose=1, callbacks=[checkpoint_es])
# Out:
# Epoch 1/500
# 52/52 [==============================] - 0s 7ms/sample - loss: 3.1246 - acc: 0.0192
# Epoch 2/500
# 52/52 [==============================] - 0s 422us/sample - loss: 3.1055 - acc: 0.0577
# Epoch 3/500
# 52/52 [==============================] - 0s 403us/sample - loss: 3.0217 - acc: 0.0769
# Epoch 4/500
# 52/52 [==============================] - 0s 422us/sample - loss: 2.9671 - acc: 0.1538
# Epoch 5/500
# 52/52 [==============================] - 0s 403us/sample - loss: 2.9452 - acc: 0.0962
# Epoch 6/500
# 52/52 [==============================] - 0s 364us/sample - loss: 2.8812 - acc: 0.1538
# Epoch 7/500
# 52/52 [==============================] - 0s 460us/sample - loss: 2.7320 - acc: 0.2115
# Epoch 8/500
# 52/52 [==============================] - 0s 403us/sample - loss: 2.7576 - acc: 0.1731
# Epoch 9/500
# 52/52 [==============================] - 0s 345us/sample - loss: 2.6513 - acc: 0.2885
# Epoch 10/500
# 52/52 [==============================] - 0s 422us/sample - loss: 2.5467 - acc: 0.2885
# Epoch 11/500
# 52/52 [==============================] - 0s 384us/sample - loss: 2.4471 - acc: 0.4038
# Epoch 12/500
# 52/52 [==============================] - 0s 364us/sample - loss: 2.4676 - acc: 0.3269
# Epoch 13/500
# 52/52 [==============================] - 0s 441us/sample - loss: 2.3356 - acc: 0.3269
# Epoch 14/500
# 52/52 [==============================] - 0s 384us/sample - loss: 2.3065 - acc: 0.3077
# Epoch 15/500
# 52/52 [==============================] - 0s 364us/sample - loss: 2.1913 - acc: 0.3846
# Epoch 16/500
# 52/52 [==============================] - 0s 422us/sample - loss: 2.0256 - acc: 0.4038
# Epoch 17/500
# 52/52 [==============================] - 0s 384us/sample - loss: 2.0110 - acc: 0.4423
# Epoch 18/500
# 52/52 [==============================] - 0s 403us/sample - loss: 1.8821 - acc: 0.5769
# Epoch 19/500
# 52/52 [==============================] - 0s 441us/sample - loss: 1.7114 - acc: 0.6538
# Epoch 20/500
# 52/52 [==============================] - 0s 384us/sample - loss: 1.6048 - acc: 0.6346
# Epoch 21/500
# 52/52 [==============================] - 0s 364us/sample - loss: 1.5673 - acc: 0.5385
# Epoch 22/500
# 52/52 [==============================] - 0s 422us/sample - loss: 1.5398 - acc: 0.5385
# Epoch 23/500
# 52/52 [==============================] - 0s 384us/sample - loss: 1.4687 - acc: 0.6346
# Epoch 24/500
# 52/52 [==============================] - 0s 345us/sample - loss: 1.4222 - acc: 0.6346
# Epoch 25/500
# 52/52 [==============================] - 0s 441us/sample - loss: 1.3442 - acc: 0.6731
# Epoch 26/500
# 52/52 [==============================] - 0s 403us/sample - loss: 1.2807 - acc: 0.6538
# Epoch 27/500
# 52/52 [==============================] - 0s 345us/sample - loss: 1.0847 - acc: 0.6923
# Epoch 28/500
# 52/52 [==============================] - 0s 422us/sample - loss: 1.1459 - acc: 0.7115
# Epoch 29/500
# 52/52 [==============================] - 0s 383us/sample - loss: 1.0566 - acc: 0.7115
# Epoch 30/500
# 52/52 [==============================] - 0s 364us/sample - loss: 1.0917 - acc: 0.7115
# Epoch 31/500
# 52/52 [==============================] - 0s 422us/sample - loss: 1.2140 - acc: 0.6538
# Epoch 32/500
# 52/52 [==============================] - 0s 384us/sample - loss: 1.2186 - acc: 0.6154
# Epoch 33/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.9581 - acc: 0.7308
# Epoch 34/500
# 52/52 [==============================] - 0s 422us/sample - loss: 1.0214 - acc: 0.7308
# Epoch 35/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.8891 - acc: 0.8269
# Epoch 36/500
# 52/52 [==============================] - ETA: 0s - loss: 0.6015 - acc: 0.800 - 0s 345us/sample - loss: 0.7692 - acc: 0.8077
# Epoch 37/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.7274 - acc: 0.7885
# Epoch 38/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.9510 - acc: 0.7692
# Epoch 39/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.6601 - acc: 0.8269
# Epoch 40/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.8175 - acc: 0.7692
# Epoch 41/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.7854 - acc: 0.8269
# Epoch 42/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.8158 - acc: 0.7692
# Epoch 43/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.6086 - acc: 0.8077
# Epoch 44/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.7624 - acc: 0.8077
# Epoch 45/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.6641 - acc: 0.8654
# Epoch 46/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.6989 - acc: 0.7115
# Epoch 47/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.5030 - acc: 0.9231
# Epoch 48/500
# 52/52 [==============================] - 0s 402us/sample - loss: 0.4359 - acc: 0.9038
# Epoch 49/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.5295 - acc: 0.8462
# Epoch 50/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.4919 - acc: 0.9231
# Epoch 51/500
# 52/52 [==============================] - ETA: 0s - loss: 0.4045 - acc: 0.800 - 0s 422us/sample - loss: 0.5584 - acc: 0.8077
# Epoch 52/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.4156 - acc: 0.9615
# Epoch 53/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.4267 - acc: 0.9038
# Epoch 54/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.4569 - acc: 0.9231
# Epoch 55/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.6959 - acc: 0.8462
# Epoch 56/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.3832 - acc: 0.9038
# Epoch 57/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.4528 - acc: 0.8846
# Epoch 58/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.4328 - acc: 0.8846
# Epoch 59/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.3895 - acc: 0.9231
# Epoch 60/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.4395 - acc: 0.8654
# Epoch 61/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.2621 - acc: 0.9231
# Epoch 62/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.3505 - acc: 0.9231
# Epoch 63/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.3314 - acc: 0.9231
# Epoch 64/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.3469 - acc: 0.9615
# Epoch 65/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.2094 - acc: 0.9615
# Epoch 66/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1955 - acc: 0.9615
# Epoch 67/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.3685 - acc: 0.9038
# Epoch 68/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.2673 - acc: 0.9423
# Epoch 69/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2773 - acc: 0.8846
# Epoch 70/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2284 - acc: 0.9615
# Epoch 71/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2981 - acc: 0.9615
# Epoch 72/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2725 - acc: 0.9423
# Epoch 73/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2093 - acc: 0.9615
# Epoch 74/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2168 - acc: 0.9423
# Epoch 75/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.3034 - acc: 0.9423
# Epoch 76/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.3233 - acc: 0.9231
# Epoch 77/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2555 - acc: 0.9231
# Epoch 78/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2817 - acc: 0.8846
# Epoch 79/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.4989 - acc: 0.8846
# Epoch 80/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2494 - acc: 0.9231
# Epoch 81/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1601 - acc: 1.0000
# Epoch 82/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2194 - acc: 0.9423
# Epoch 83/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1906 - acc: 0.9423
# Epoch 84/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2098 - acc: 0.9808
# Epoch 85/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2348 - acc: 0.9423
# Epoch 86/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2040 - acc: 0.9808
# Epoch 87/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2249 - acc: 0.9231
# Epoch 88/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.3210 - acc: 0.9038
# Epoch 89/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.3462 - acc: 0.9038
# Epoch 90/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1577 - acc: 0.9615
# Epoch 91/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2092 - acc: 1.0000
# Epoch 92/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.3059 - acc: 0.9038
# Epoch 93/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2005 - acc: 0.9423
# Epoch 94/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1755 - acc: 0.9423
# Epoch 95/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1529 - acc: 0.9615
# Epoch 96/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.1287 - acc: 0.9615
# Epoch 97/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.0958 - acc: 0.9808
# Epoch 98/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.2626 - acc: 0.8846
# Epoch 99/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1425 - acc: 0.9615
# Epoch 100/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.2460 - acc: 0.8846
# Epoch 101/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1189 - acc: 0.9808
# Epoch 102/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.3304 - acc: 0.9423
# Epoch 103/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.2126 - acc: 0.9423
# Epoch 104/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1979 - acc: 0.9615
# Epoch 105/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1624 - acc: 0.9615
# Epoch 106/500
# 52/52 [==============================] - 0s 480us/sample - loss: 0.0857 - acc: 0.9808
# Epoch 107/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.1546 - acc: 0.9231
# Epoch 108/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0813 - acc: 1.0000
# Epoch 109/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1314 - acc: 0.9808
# Epoch 110/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1720 - acc: 0.9615
# Epoch 111/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1314 - acc: 0.9615
# Epoch 112/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0962 - acc: 0.9808
# Epoch 113/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.1066 - acc: 1.0000
# Epoch 114/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1294 - acc: 0.9615
# Epoch 115/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.1752 - acc: 0.9423
# Epoch 116/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1250 - acc: 0.9808
# Epoch 117/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.2188 - acc: 0.9423
# Epoch 118/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1397 - acc: 0.9423
# Epoch 119/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.2374 - acc: 0.9615
# Epoch 120/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1869 - acc: 0.9231
# Epoch 121/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0950 - acc: 1.0000
# Epoch 122/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0535 - acc: 1.0000
# Epoch 123/500
# 52/52 [==============================] - 0s 383us/sample - loss: 0.2187 - acc: 0.8846
# Epoch 124/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1334 - acc: 0.9808
# Epoch 125/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1371 - acc: 0.9808
# Epoch 126/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1595 - acc: 0.9423
# Epoch 127/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0994 - acc: 0.9808
# Epoch 128/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1546 - acc: 0.9615
# Epoch 129/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1196 - acc: 0.9615
# Epoch 130/500
# 52/52 [==============================] - 0s 461us/sample - loss: 0.1387 - acc: 0.9615
# Epoch 131/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0743 - acc: 0.9808
# Epoch 132/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0878 - acc: 1.0000
# Epoch 133/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.2158 - acc: 0.9423
# Epoch 134/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1431 - acc: 0.9615
# Epoch 135/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.1077 - acc: 0.9615
# Epoch 136/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.2133 - acc: 0.9231
# Epoch 137/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1290 - acc: 0.9615
# Epoch 138/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1224 - acc: 0.9615
# Epoch 139/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1264 - acc: 0.9615
# Epoch 140/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.1903 - acc: 0.9423
# Epoch 141/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1345 - acc: 0.9423
# Epoch 142/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0911 - acc: 1.0000
# Epoch 143/500
# 52/52 [==============================] - 0s 595us/sample - loss: 0.0927 - acc: 0.9808
# Epoch 144/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.2467 - acc: 0.9231
# Epoch 145/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1211 - acc: 0.9615
# Epoch 146/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.1685 - acc: 0.9615
# Epoch 147/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0459 - acc: 1.0000
# Epoch 148/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1672 - acc: 0.9231
# Epoch 149/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.0894 - acc: 1.0000
# Epoch 150/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0960 - acc: 0.9808
# Epoch 151/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1130 - acc: 0.9615
# Epoch 152/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0991 - acc: 0.9808
# Epoch 153/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1025 - acc: 0.9808
# Epoch 154/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0473 - acc: 1.0000
# Epoch 155/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.2000 - acc: 0.9231
# Epoch 156/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1366 - acc: 0.9615
# Epoch 157/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1389 - acc: 0.9615
# Epoch 158/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0973 - acc: 0.9808
# Epoch 159/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1211 - acc: 0.9808
# Epoch 160/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1421 - acc: 0.9231
# Epoch 161/500
# 52/52 [==============================] - 0s 480us/sample - loss: 0.1679 - acc: 0.9615
# Epoch 162/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0985 - acc: 0.9615
# Epoch 163/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.1015 - acc: 0.9808
# Epoch 164/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1423 - acc: 0.9231
# Epoch 165/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1505 - acc: 0.9423
# Epoch 166/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.1994 - acc: 0.9231
# Epoch 167/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0708 - acc: 1.0000
# Epoch 168/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1652 - acc: 0.9231
# Epoch 169/500
# 52/52 [==============================] - 0s 402us/sample - loss: 0.0705 - acc: 0.9808
# Epoch 170/500
# 52/52 [==============================] - 0s 500us/sample - loss: 0.0400 - acc: 1.0000
# Epoch 171/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.0617 - acc: 0.9808
# Epoch 172/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1669 - acc: 0.9615
# Epoch 173/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0936 - acc: 0.9808
# Epoch 174/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1716 - acc: 0.9423
# Epoch 175/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0668 - acc: 0.9808
# Epoch 176/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.2522 - acc: 0.9231
# Epoch 177/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0928 - acc: 0.9615
# Epoch 178/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.2427 - acc: 0.9231
# Epoch 179/500
# 52/52 [==============================] - 0s 537us/sample - loss: 0.1359 - acc: 0.9808
# Epoch 180/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.1365 - acc: 0.9615
# Epoch 181/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.0466 - acc: 1.0000
# Epoch 182/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0906 - acc: 0.9808
# Epoch 183/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0764 - acc: 0.9615
# Epoch 184/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.1207 - acc: 0.9808
# Epoch 185/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0846 - acc: 0.9808
# Epoch 186/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.1116 - acc: 0.9615
# Epoch 187/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1011 - acc: 0.9423
# Epoch 188/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0565 - acc: 0.9808
# Epoch 189/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0682 - acc: 1.0000
# Epoch 190/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0811 - acc: 0.9808
# Epoch 191/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1166 - acc: 0.9615
# Epoch 192/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.1233 - acc: 0.9615
# Epoch 193/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0659 - acc: 0.9808
# Epoch 194/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0734 - acc: 0.9808
# Epoch 195/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0523 - acc: 0.9808
# Epoch 196/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0828 - acc: 1.0000
# Epoch 197/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1707 - acc: 0.9423
# Epoch 198/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0888 - acc: 0.9615
# Epoch 199/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0909 - acc: 0.9808
# Epoch 200/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0318 - acc: 1.0000
# Epoch 201/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1164 - acc: 0.9423
# Epoch 202/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0435 - acc: 1.0000
# Epoch 203/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0702 - acc: 1.0000
# Epoch 204/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1231 - acc: 0.9423
# Epoch 205/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0373 - acc: 1.0000
# Epoch 206/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0338 - acc: 1.0000
# Epoch 207/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0597 - acc: 1.0000
# Epoch 208/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1031 - acc: 0.9423
# Epoch 209/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0866 - acc: 0.9808
# Epoch 210/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0193 - acc: 1.0000
# Epoch 211/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1243 - acc: 0.9423
# Epoch 212/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0322 - acc: 1.0000
# Epoch 213/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0975 - acc: 0.9615
# Epoch 214/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0317 - acc: 1.0000
# Epoch 215/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0435 - acc: 0.9808
# Epoch 216/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0255 - acc: 1.0000
# Epoch 217/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0849 - acc: 0.9808
# Epoch 218/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0792 - acc: 0.9808
# Epoch 219/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0610 - acc: 1.0000
# Epoch 220/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0465 - acc: 0.9808
# Epoch 221/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0353 - acc: 1.0000
# Epoch 222/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0343 - acc: 0.9808
# Epoch 223/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0862 - acc: 0.9808
# Epoch 224/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0869 - acc: 0.9615
# Epoch 225/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0900 - acc: 0.9808
# Epoch 226/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0440 - acc: 1.0000
# Epoch 227/500
# 52/52 [==============================] - 0s 346us/sample - loss: 0.0775 - acc: 1.0000
# Epoch 228/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0292 - acc: 1.0000
# Epoch 229/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0467 - acc: 0.9808
# Epoch 230/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0888 - acc: 0.9615
# Epoch 231/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0376 - acc: 0.9808
# Epoch 232/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.0473 - acc: 1.0000
# Epoch 233/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0146 - acc: 1.0000
# Epoch 234/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0411 - acc: 0.9808
# Epoch 235/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0657 - acc: 0.9808
# Epoch 236/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0615 - acc: 0.9808
# Epoch 237/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0447 - acc: 1.0000
# Epoch 238/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0651 - acc: 0.9808
# Epoch 239/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0514 - acc: 1.0000
# Epoch 240/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1072 - acc: 0.9615
# Epoch 241/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0661 - acc: 0.9808
# Epoch 242/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0362 - acc: 1.0000
# Epoch 243/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1025 - acc: 0.9231
# Epoch 244/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1264 - acc: 0.9423
# Epoch 245/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0828 - acc: 0.9615
# Epoch 246/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0808 - acc: 0.9615
# Epoch 247/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1252 - acc: 0.9615
# Epoch 248/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0827 - acc: 1.0000
# Epoch 249/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0910 - acc: 0.9615
# Epoch 250/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0983 - acc: 0.9615
# Epoch 251/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0726 - acc: 0.9808
# Epoch 252/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0368 - acc: 0.9808
# Epoch 253/500
# 52/52 [==============================] - ETA: 0s - loss: 0.0603 - acc: 1.000 - 0s 362us/sample - loss: 0.0463 - acc: 1.0000
# Epoch 254/500
# 52/52 [==============================] - 0s 354us/sample - loss: 0.0738 - acc: 0.9808
# Epoch 255/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.0697 - acc: 0.9615
# Epoch 256/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0222 - acc: 1.0000
# Epoch 257/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0150 - acc: 1.0000
# Epoch 258/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0655 - acc: 0.9808
# Epoch 259/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0195 - acc: 1.0000
# Epoch 260/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0518 - acc: 0.9808
# Epoch 261/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1436 - acc: 0.9423
# Epoch 262/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0448 - acc: 0.9808
# Epoch 263/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0756 - acc: 0.9615
# Epoch 264/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0593 - acc: 0.9808
# Epoch 265/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0475 - acc: 1.0000
# Epoch 266/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0958 - acc: 0.9615
# Epoch 267/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0240 - acc: 1.0000
# Epoch 268/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0104 - acc: 1.0000
# Epoch 269/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0929 - acc: 0.9808
# Epoch 270/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0256 - acc: 1.0000
# Epoch 271/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0983 - acc: 0.9615
# Epoch 272/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0526 - acc: 0.9808
# Epoch 273/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0627 - acc: 1.0000
# Epoch 274/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0648 - acc: 1.0000
# Epoch 275/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0083 - acc: 1.0000
# Epoch 276/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0570 - acc: 1.0000
# Epoch 277/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0253 - acc: 1.0000
# Epoch 278/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0187 - acc: 1.0000
# Epoch 279/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0842 - acc: 0.9808
# Epoch 280/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0753 - acc: 0.9808
# Epoch 281/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0435 - acc: 1.0000
# Epoch 282/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0527 - acc: 1.0000
# Epoch 283/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0994 - acc: 0.9615
# Epoch 284/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0451 - acc: 1.0000
# Epoch 285/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0523 - acc: 1.0000
# Epoch 286/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0170 - acc: 1.0000
# Epoch 287/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0663 - acc: 0.9808
# Epoch 288/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0695 - acc: 0.9808
# Epoch 289/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0150 - acc: 1.0000
# Epoch 290/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0841 - acc: 0.9615
# Epoch 291/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0787 - acc: 0.9615
# Epoch 292/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0387 - acc: 1.0000
# Epoch 293/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0296 - acc: 1.0000
# Epoch 294/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0229 - acc: 1.0000
# Epoch 295/500
# 52/52 [==============================] - 0s 575us/sample - loss: 0.0337 - acc: 1.0000
# Epoch 296/500
# 52/52 [==============================] - 0s 614us/sample - loss: 0.0135 - acc: 1.0000
# Epoch 297/500
# 52/52 [==============================] - 0s 556us/sample - loss: 0.0094 - acc: 1.0000
# Epoch 298/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0102 - acc: 1.0000
# Epoch 299/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0357 - acc: 1.0000
# Epoch 300/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1557 - acc: 0.9423
# Epoch 301/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0585 - acc: 1.0000
# Epoch 302/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0346 - acc: 1.0000
# Epoch 303/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0309 - acc: 1.0000
# Epoch 304/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0759 - acc: 1.0000
# Epoch 305/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1423 - acc: 0.9615
# Epoch 306/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0300 - acc: 1.0000
# Epoch 307/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0613 - acc: 1.0000
# Epoch 308/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0507 - acc: 0.9808
# Epoch 309/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0083 - acc: 1.0000
# Epoch 310/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0344 - acc: 1.0000
# Epoch 311/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0926 - acc: 0.9808
# Epoch 312/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0728 - acc: 0.9808
# Epoch 313/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0272 - acc: 1.0000
# Epoch 314/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0299 - acc: 1.0000
# Epoch 315/500
# 52/52 [==============================] - 0s 537us/sample - loss: 0.0372 - acc: 0.9808
# Epoch 316/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0628 - acc: 0.9615
# Epoch 317/500
# 52/52 [==============================] - 0s 537us/sample - loss: 0.0408 - acc: 1.0000
# Epoch 318/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0489 - acc: 1.0000
# Epoch 319/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0446 - acc: 0.9808
# Epoch 320/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0507 - acc: 1.0000
# Epoch 321/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0890 - acc: 0.9615
# Epoch 322/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0497 - acc: 0.9808
# Epoch 323/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0493 - acc: 0.9808
# Epoch 324/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0068 - acc: 1.0000
# Epoch 325/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0637 - acc: 1.0000
# Epoch 326/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0401 - acc: 1.0000
# Epoch 327/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0476 - acc: 1.0000
# Epoch 328/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0195 - acc: 1.0000
# Epoch 329/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0578 - acc: 0.9808
# Epoch 330/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0781 - acc: 0.9615
# Epoch 331/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0315 - acc: 1.0000
# Epoch 332/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0102 - acc: 1.0000
# Epoch 333/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1414 - acc: 0.9423
# Epoch 334/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0675 - acc: 0.9423
# Epoch 335/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0845 - acc: 0.9808
# Epoch 336/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0528 - acc: 0.9808
# Epoch 337/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0222 - acc: 1.0000
# Epoch 338/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0337 - acc: 1.0000
# Epoch 339/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0125 - acc: 1.0000
# Epoch 340/500
# 52/52 [==============================] - 0s 499us/sample - loss: 0.0294 - acc: 1.0000
# Epoch 341/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.1015 - acc: 0.9808
# Epoch 342/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0158 - acc: 1.0000
# Epoch 343/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0825 - acc: 0.9615
# Epoch 344/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.1418 - acc: 0.9615
# Epoch 345/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0544 - acc: 0.9808
# Epoch 346/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0332 - acc: 1.0000
# Epoch 347/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.0479 - acc: 0.9808
# Epoch 348/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0226 - acc: 0.9808
# Epoch 349/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0062 - acc: 1.0000
# Epoch 350/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0440 - acc: 1.0000
# Epoch 351/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1170 - acc: 0.9808
# Epoch 352/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0798 - acc: 0.9808
# Epoch 353/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0239 - acc: 1.0000
# Epoch 354/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0446 - acc: 0.9808
# Epoch 355/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1316 - acc: 0.9423
# Epoch 356/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0146 - acc: 1.0000
# Epoch 357/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0610 - acc: 0.9808
# Epoch 358/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0762 - acc: 0.9808
# Epoch 359/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0348 - acc: 0.9808
# Epoch 360/500
# 52/52 [==============================] - 0s 480us/sample - loss: 0.0377 - acc: 0.9808
# Epoch 361/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0413 - acc: 0.9615
# Epoch 362/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0458 - acc: 1.0000
# Epoch 363/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0125 - acc: 1.0000
# Epoch 364/500
# 52/52 [==============================] - 0s 518us/sample - loss: 0.0262 - acc: 1.0000
# Epoch 365/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0513 - acc: 0.9808
# Epoch 366/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0224 - acc: 1.0000
# Epoch 367/500
# 52/52 [==============================] - ETA: 0s - loss: 0.0012 - acc: 1.000 - 0s 422us/sample - loss: 0.0233 - acc: 1.0000
# Epoch 368/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0342 - acc: 0.9808
# Epoch 369/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0245 - acc: 1.0000
# Epoch 370/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0331 - acc: 1.0000
# Epoch 371/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0457 - acc: 1.0000
# Epoch 372/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0166 - acc: 1.0000
# Epoch 373/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0518 - acc: 0.9808
# Epoch 374/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0363 - acc: 1.0000
# Epoch 375/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0298 - acc: 1.0000
# Epoch 376/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0716 - acc: 0.9808
# Epoch 377/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0534 - acc: 0.9808
# Epoch 378/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0557 - acc: 0.9808
# Epoch 379/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0137 - acc: 1.0000
# Epoch 380/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0180 - acc: 1.0000
# Epoch 381/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0323 - acc: 1.0000
# Epoch 382/500
# 52/52 [==============================] - 0s 346us/sample - loss: 0.0754 - acc: 0.9615
# Epoch 383/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0765 - acc: 0.9808
# Epoch 384/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0258 - acc: 0.9808
# Epoch 385/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1269 - acc: 0.9615
# Epoch 386/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0744 - acc: 0.9808
# Epoch 387/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0345 - acc: 0.9808
# Epoch 388/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0458 - acc: 0.9808
# Epoch 389/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0772 - acc: 0.9808
# Epoch 390/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0600 - acc: 0.9808
# Epoch 391/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0321 - acc: 1.0000
# Epoch 392/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0247 - acc: 0.9808
# Epoch 393/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0353 - acc: 1.0000
# Epoch 394/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0753 - acc: 0.9808
# Epoch 395/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0831 - acc: 0.9808
# Epoch 396/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0204 - acc: 1.0000
# Epoch 397/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0364 - acc: 0.9808
# Epoch 398/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0676 - acc: 0.9615
# Epoch 399/500
# 52/52 [==============================] - 0s 498us/sample - loss: 0.0340 - acc: 1.0000
# Epoch 400/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0327 - acc: 1.0000
# Epoch 401/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0229 - acc: 1.0000
# Epoch 402/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0670 - acc: 0.9808
# Epoch 403/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0260 - acc: 1.0000
# Epoch 404/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0357 - acc: 0.9808
# Epoch 405/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0177 - acc: 1.0000
# Epoch 406/500
# 52/52 [==============================] - ETA: 0s - loss: 0.0019 - acc: 1.000 - 0s 422us/sample - loss: 0.0167 - acc: 1.0000
# Epoch 407/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0749 - acc: 0.9615
# Epoch 408/500
# 52/52 [==============================] - 0s 365us/sample - loss: 0.0447 - acc: 0.9808
# Epoch 409/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0774 - acc: 0.9808
# Epoch 410/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0086 - acc: 1.0000
# Epoch 411/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0446 - acc: 0.9808
# Epoch 412/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0638 - acc: 0.9615
# Epoch 413/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0245 - acc: 1.0000
# Epoch 414/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0098 - acc: 1.0000
# Epoch 415/500
# 52/52 [==============================] - 0s 479us/sample - loss: 0.0354 - acc: 0.9808
# Epoch 416/500
# 52/52 [==============================] - 0s 460us/sample - loss: 0.0368 - acc: 1.0000
# Epoch 417/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0340 - acc: 1.0000
# Epoch 418/500
# 52/52 [==============================] - 0s 480us/sample - loss: 0.0262 - acc: 1.0000
# Epoch 419/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0167 - acc: 1.0000
# Epoch 420/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0590 - acc: 0.9808
# Epoch 421/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0438 - acc: 1.0000
# Epoch 422/500
# 52/52 [==============================] - 0s 441us/sample - loss: 0.0034 - acc: 1.0000
# Epoch 423/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0418 - acc: 0.9808
# Epoch 424/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0091 - acc: 1.0000
# Epoch 425/500
# 52/52 [==============================] - 0s 422us/sample - loss: 0.0119 - acc: 1.0000
# Epoch 426/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0938 - acc: 0.9615
# Epoch 427/500
# 52/52 [==============================] - 0s 403us/sample - loss: 0.0282 - acc: 1.0000
# Epoch 428/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0990 - acc: 0.9808
# Epoch 429/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0283 - acc: 1.0000
# Epoch 430/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0384 - acc: 1.0000
# Epoch 431/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0311 - acc: 1.0000
# Epoch 432/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.1105 - acc: 0.9615
# Epoch 433/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0169 - acc: 1.0000
# Epoch 434/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0232 - acc: 1.0000
# Epoch 435/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0118 - acc: 1.0000
# Epoch 436/500
# 52/52 [==============================] - ETA: 0s - loss: 1.8947e-04 - acc: 1.000 - 0s 364us/sample - loss: 0.0064 - acc: 1.0000
# Epoch 437/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0466 - acc: 0.9808
# Epoch 438/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0551 - acc: 0.9808
# Epoch 439/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1363 - acc: 0.9231
# Epoch 440/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0333 - acc: 0.9808
# Epoch 441/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0067 - acc: 1.0000
# Epoch 442/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0110 - acc: 1.0000
# Epoch 443/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0182 - acc: 1.0000
# Epoch 444/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0402 - acc: 0.9808
# Epoch 445/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0319 - acc: 1.0000
# Epoch 446/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0732 - acc: 0.9808
# Epoch 447/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0220 - acc: 1.0000
# Epoch 448/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0268 - acc: 1.0000
# Epoch 449/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0689 - acc: 0.9615
# Epoch 450/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0128 - acc: 1.0000
# Epoch 451/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0508 - acc: 0.9808
# Epoch 452/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0106 - acc: 1.0000
# Epoch 453/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0195 - acc: 1.0000
# Epoch 454/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0349 - acc: 0.9808
# Epoch 455/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0262 - acc: 1.0000
# Epoch 456/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0201 - acc: 1.0000
# Epoch 457/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0051 - acc: 1.0000
# Epoch 458/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0347 - acc: 0.9808
# Epoch 459/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0403 - acc: 1.0000
# Epoch 460/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0497 - acc: 0.9808
# Epoch 461/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0334 - acc: 0.9808
# Epoch 462/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0052 - acc: 1.0000
# Epoch 463/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0146 - acc: 1.0000
# Epoch 464/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0371 - acc: 1.0000
# Epoch 465/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0223 - acc: 0.9808
# Epoch 466/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0040 - acc: 1.0000
# Epoch 467/500
# 52/52 [==============================] - ETA: 0s - loss: 0.0900 - acc: 1.000 - 0s 346us/sample - loss: 0.0241 - acc: 1.0000
# Epoch 468/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0501 - acc: 0.9808
# Epoch 469/500
# 52/52 [==============================] - 0s 326us/sample - loss: 0.0553 - acc: 0.9808
# Epoch 470/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0371 - acc: 0.9808
# Epoch 471/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0119 - acc: 1.0000
# Epoch 472/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0280 - acc: 1.0000
# Epoch 473/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0064 - acc: 1.0000
# Epoch 474/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0154 - acc: 1.0000
# Epoch 475/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0662 - acc: 0.9808
# Epoch 476/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0145 - acc: 1.0000
# Epoch 477/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0286 - acc: 0.9808
# Epoch 478/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0071 - acc: 1.0000
# Epoch 479/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0504 - acc: 0.9808
# Epoch 480/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0448 - acc: 1.0000
# Epoch 481/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0493 - acc: 0.9808
# Epoch 482/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0471 - acc: 1.0000
# Epoch 483/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.1039 - acc: 0.9615
# Epoch 484/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0228 - acc: 0.9808
# Epoch 485/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0183 - acc: 1.0000
# Epoch 486/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0065 - acc: 1.0000
# Epoch 487/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0307 - acc: 0.9808
# Epoch 488/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0230 - acc: 0.9808
# Epoch 489/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0113 - acc: 1.0000
# Epoch 490/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0161 - acc: 1.0000
# Epoch 491/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0644 - acc: 0.9808
# Epoch 492/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0371 - acc: 0.9808
# Epoch 493/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0609 - acc: 0.9808
# Epoch 494/500
# 52/52 [==============================] - 0s 345us/sample - loss: 0.0308 - acc: 0.9808
# Epoch 495/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0205 - acc: 1.0000
# Epoch 496/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0396 - acc: 0.9808
# Epoch 497/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0046 - acc: 1.0000
# Epoch 498/500
# 52/52 [==============================] - 0s 384us/sample - loss: 0.0205 - acc: 1.0000
# Epoch 499/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0167 - acc: 1.0000
# Epoch 500/500
# 52/52 [==============================] - 0s 364us/sample - loss: 0.0330 - acc: 0.9808

# %% [markdown]
# ## Preprocess User Query

# %%
# performs preprocessing on inputted text (lower casing and lemmatization)
def preprocess_input(text):
    text_token = nltk.word_tokenize(text)
    text_token = [lem.lemmatize(word.lower()) for word in text_token]
    return text_token

# coverts preprocessed text to a matrix form 
def bow_en(text_token):
    bag = []
    for word in words_en:
        if word in text_token:
            bag.append(1)
        else:
            bag.append(0)
    return bag

def bow_es(text_token):
    bag = []
    for word in words_es:
        if word in text_token:
            bag.append(1)
        else:
            bag.append(0)
    return bag

# inputs user query in matrix form and returns a predicted label 
def predict_label_en(bow_en):
    prediction = model_en.predict(np.array(bow_en).reshape((1, len(words_en))))
    max_value = np.max(prediction)
    if max_value > 0.7:
        predict_label = labels_en[np.argmax(prediction)]
    else:
        predict_label = 'NA'
    return predict_label

def predict_label_es(bow_es):
    prediction = model_es.predict(np.array(bow_es).reshape((1, len(words_es))))
    max_value = np.max(prediction)
    if max_value > 0.7:
        predict_label = labels_es[np.argmax(prediction)]
    else:
        predict_label = 'NA'
    return predict_label

# %% [markdown]
# ## Response Generation

# %% [markdown]
# ### English Responses

# %%
# inputs the user intent and returns the appropriate response
def generate_response_en(query_intent, user):
    
    
    responses_en = { 
        'cancel' : "Ok, it's cancelled. Once you're ready, please type *`daily`* to fill out your follow-up reports.",

        'chicken' : "Here comes Arthur!\n\n*[Launch Rubber Chicken]({{{url}}})* 🐔\n\n_Pro tip: you can change the last part of Arthur's URL in your browser in order to create a unique room.",

        'daily' :  "No response",
            
        'dailystatus' : "No response",
            
        'dashboard' :"Ok, please *[follow this link]({{{url}}})* to access the web dashboard.",

        'datetime' :  "The time information for your user is:",
            
        'disable' : "Ok, it's done. You have disconnected and disabled all private messaging between you and me.\nYou can still use the [web application]({{{url}}}).\n\nIf you want to talk to me again, just type *`enable`*",


        'enable' : "It seems that you had enabled me previously, I'm ready to help you.\nPlease type *`help`* to know more about how I can help you.",
                    # 8. "Hey! Welcome back, I'm ready to help you.\nYou can *[login into the web application]({{{url}}})* to check your settings."
            
        'extras' :"Hey, your wish is my command, and these are the extra commands",
            
        'feedback' : "Hey {}, it'd be great to get some feedback from you. If it's something important, I recommend you to visit our support center.".format(user.first_name),

        'hello' : "Hey {}! Have a great day and remember I'm so happy about being your friend.\nType *`help`* to learn more about me.".format(user.first_name),

        'help' : "Hey, your wish is my command, and these are my available commands:",

        'kudos' :  "kudos response: ",
        
        'news' :  "Take a look at *[my blog](https://www.dailybot.co/blog/)* to read about tips, key learnings and other content that our team is sharing.",

        'report' : 'No response',
        
        'resetdaily' :"This command has been changed, please type *`help`* to see all current commands.",

        'settings' : "This is a quick overview of your settings. You can manage these settings on my *[Web Application]({{{url}}})*:",

        'skipdaily' :"no response",
        
        'snooze' : "Ok, I’ll remind you in *{{time}} minutes*",

        'textformat' : "Hi there! The following is a list of the different formats I support.\nYou can also see this *[support article](https://www.dailybot.com)* to know more about how to build responses with these formats.",

        'thanks' : ["Oh, don't you even mention it. I'm always happy to help.",
                                "It's always my pleasure.",
                                "You are so very welcome.",
                                "It's no trouble at all. 😊",
                                "Anytime! it's always my pleasure. 😊"],
       
        'timezone' : "The time information for the typed timezone is:",

        'NA':  "Sorry for not understanding. Please type *`help`* for me to help you."
        
        
        
    }

    return responses_en[query_intent]

# %% [markdown]
# ### Spanish Responses

# %%
    
# inputs the user intent and returns the appropriate response
def generate_response_es(query_intent, user):
    
    responses_es = { 
        'cancel' : "Ok, has cancelado tu seguimiento diario. Por favor escribe *`daily`* para empezar cuando desees.",
    
        'chicken' : "¡Aquí viene Arthur!\n\n[Abrir Rubber Chicken]({{{url}}}) 🐔\n\n_Pro tip: puedes cambiar la última parte de la URL de Arthur en tu navegador y así tendrás una sala única._",

        'daily' :  "No hay respuesta",
        
        'dailystatus' :  "No hay respuesta",
        
        'dashboard' : "Ok, *[abre este enlace]({{{url}}})* para abrir la web y dashboard.",

        'datetime' : "La información horaria de tu usuario es:",

        'disable' : "Listo, está hecho. Has desconectado y deshabilitado todos los mensajes privados entre tu y yo.\nPor cierto, puedes seguir utilizando mi [aplicación web]({{{url}}}).\n\nSi deseas volver a hablar conmigo simplemente escribe *`enable`*.",

        'enable' : "Parece que ya me habías habilitado previamente, estoy listo para ayudarte.\nPor favor, escribe *`help`* para saber más sobre cómo puedo ayudarte.",
                    # 8. "¡Hola! Bienvenido de nuevo, estoy listo para ayudarte.\nPor favor inicia sesión en mi *[aplicación web]({{{url}}})* para confirmar su configuración."
        
        'extras' : "Hola, puedes usar estos comandos extras para interactuar conmigo:",

        
        'feedback' : "Hola {}!, Sería grandióso recibir tu feedback. Si es algo importante, Te recomiendo visitar nuestro centro de soporte.".format(user.first_name),

        
        'hello' :  "¡Hola {}! Ten un excelente día y recuerda que estoy muy feliz de ser tu amigo.\nEscribe *`help`* para aprender más sobre mí.".format(user.first_name),

        
        'help' : "Hola, puedes usar estos comandos para interactuar conmigo:",
        
        'kudos' :"kudos response: ",
        
        'news' : "Echa un vistazo a *[mi blog](https://www.dailybot.com/blog/)* (en inglés) para leer sobre trucos, aprendizajes y otro contenido que comparte nuestro equipo.",

        
        'report' : "No hay respuesta",
        
        'resetdaily' : "Este comando ha cambiado, por favor escribe *`help`* para ver todos los comandos actuales.",

        'settings' : "Este es un resúmen de tu configuración. Puedes gestionar la configuración en mi *[aplicación web]({{{url}}})*:",

        'skipdaily' : "No hay respuesta",
        
        'snooze' : "Ok, te recordaré en *{{time}} minutos*.",

        'textformat' : "Hola! La siguiente es una lista de los diferentes formatos que soporto.\nPuedes verlo aquí *[artículo de apoyo](https://www.dailybot.com)* para conocer más acerca de como construir respuestas con estos formatos.",

        'thanks' : ["¡Con muuucho gusto!",
                                 "Siempre es un placer.",
                                 "Estoy para ayudarte.",
                                 "A ti por tu tiempo. 😊",
                                 "¡Cuando me necesites! siempre es un placer. 😊"],
    
        'timezone' :  "La información de la zona horaria introducida es:",

        'NA': "Lo siento por no entender. Por favor escribe *`help`* para ayudarte."        
        
    }

    return responses_es[query_intent]

# %% [markdown]
# ## Saving unidentified Queries

# %%
# Create list of queries with no response
try:
    no_intent_queries = open("no_intent_queries.txt", "x")
except:
    pass

# %% [markdown]
# ## Load User Object

# %%
from imp import reload
import UserObjects

reload(UserObjects)

User = UserObjects.User
vars(User)

aashish = User("Aashish", "Nair", "Spanish")
print(aashish.language)
# Out:
# Spanish

# %% [markdown]
# # Chatbot

# %%
prediction = predict_label_en(np.array(bow_en(preprocess_input('feedback please'))))
prediction

print('Insert command here (type "quit" to stop chatbot)\n')

while 1 >0:
    
    input_text = input()
    if input_text=='quit':
        break
    if len(input_text) < 3:
        while len(input_text) <3:
            input_text = input_text + " "
            
    if aashish.language =='English':
        spell = Speller(lang='en')
        input_text = spell(input_text)
        prediction_en = predict_label_en(np.array(bow_en(preprocess_input(input_text))))
        if prediction_en == 'thanks':
            response_en = random.choice(generate_response_en(prediction_en, aashish))
        else:
            response_en = generate_response_en(prediction_en, aashish)
        print(response_en)
        print(' ')
        if prediction == 'NA':
            queries_list = queries_list + input_text+ '\n'
    
    elif aashish.language == 'Spanish':
        spell = Speller(lang='es')
        input_text = spell(input_text)
        prediction_es = predict_label_es(np.array(bow_es(preprocess_input(input_text))))
        if prediction_es == 'thanks':
            response_es = random.choice(generate_response_es(prediction_es, aashish))
        else:
            response_es = generate_response_es(prediction_es, aashish)
        print(response_es)
        print(' ')
        if prediction == 'NA':
            queries_list = queries_list + input_text+ '\n'
'''   
    
    prediction = predict_label(np.array(bow(preprocess_input(input_text))))
    response = generate_response(prediction)
    if prediction == 'NA':
            queries_list = queries_list + input_text+'\n'    
    

    if TextBlob(input_text).detect_language() == 'en':
        if prediction == 'thanks':
            print(random.choice(response['en']))
        else:
            print(response['en'])
    elif TextBlob(input_text).detect_language() == 'es' :
        if prediction == 'thanks':
            print(random.choice(response['es'])+'\n')
        else:
            print(response['es']+'\n')
    else:
        print("Sorry for not understanding. Please type *`help`* for me to help you.")
    print(' ')
'''
# Out:
# Insert command here (type "quit" to stop chatbot)
#
# hola
# ¡Hola Aashish! Ten un excelente día y recuerda que estoy muy feliz de ser tu amigo.
# Escribe *`help`* para aprender más sobre mí.
#
# holas
# Lo siento por no entender. Por favor escribe *`help`* para ayudarte.
#
# pollo
# ¡Aquí viene Arthur!
#
# [Abrir Rubber Chicken]({{{url}}}) 🐔
#
# _Pro tip: puedes cambiar la última parte de la URL de Arthur en tu navegador y así tendrás una sala única._
#
# pollow
# ¡Aquí viene Arthur!
#
# [Abrir Rubber Chicken]({{{url}}}) 🐔
#
# _Pro tip: puedes cambiar la última parte de la URL de Arthur en tu navegador y así tendrás una sala única._
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-161-77807c9cad51> in <module>
#       6 while 1 >0:
#       7
# ----> 8     input_text = input()
#       9     if input_text=='quit':
#      10         break
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Add "NA" Queries to .txt File

# %%
spell('Give me feedbacs')
# Out:
# 'Give me feedback'
