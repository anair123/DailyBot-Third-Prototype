# %% [markdown]
# # Libraries

# %%
import json
import nltk
import spacy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from nltk.stem import WordNetLemmatizer
import numpy as np
import random
import pickle
from textblob import TextBlob
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from textblob import TextBlob
import os
from autocorrect import Speller
from spellchecker import SpellChecker
import dateparser

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# # Load JSON Files

# %%
# English Data
data_en = json.loads(open('data_en.json').read())

# Spanish Data
data_es = json.loads(open('data_es.json').read())

# %% [markdown]
# ## Natural Language Processing

# %%
intents_en = data_en['interactionModel']['languageModel']

intents_es = data_es['interactionModel']['languageModel']

# %%
intents_en
# Out:
# {'intent': [{'name': 'hello', 'samples': ['Hi', 'Hello', 'hey']},
#   {'name': 'feedback',
#    'samples': ['feedback',
#     'I want some feedback',
#     'Give me feedback',
#     'I want feedback']},
#   {'name': 'cancel', 'samples': ['cancel', 'cancel it']},
#   {'name': 'chicken',
#    'samples': ['arthur',
#     'chicken',
#     'I want arthur',
#     'I want the chicken',
#     'Bring the chicken',
#     'about Arthur']},
#   {'name': 'dashboard',
#    'samples': ['dashboard',
#     'Show me the dashboard',
#     'Bring the dashboard',
#     'I want the dashboard',
#     'about dashboard']},
#   {'name': 'datetime',
#    'samples': ['date time',
#     'time',
#     'tell me the time',
#     'show the time',
#     'show the datetime']},
#   {'name': 'disable', 'samples': ['disable', 'disable it']},
#   {'name': 'enable', 'samples': ['enable', 'enable it', 'enable the message']},
#   {'name': 'help',
#    'samples': ['help', 'show help', 'give help', 'I want help']},
#   {'name': 'extras', 'samples': ['extras', 'show extras', 'I want extras']},
#   {'name': 'news', 'samples': ['news', 'show the news', 'I want the news']},
#   {'name': 'settings',
#    'samples': ['settings',
#     'show settings',
#     'give me settings',
#     'I want settings']},
#   {'name': 'textformat',
#    'samples': ['textformat',
#     'show the textformat',
#     'I want textformat',
#     'text format',
#     'show the text format',
#     ' I want text format']},
#   {'name': 'thanks',
#    'samples': ['thanks',
#     'thank you',
#     'thank you very much',
#     'thanks a lot',
#     'thanks so much',
#     'Thanks']},
#   {'name': 'timezone',
#    'samples': ['time zone',
#     'what is the timezone',
#     'show the timezone',
#     'I want the timezone',
#     'time zone',
#     'what is the time zone',
#     'show the time zone',
#     'I want the time zone']},
#   {'name': 'daily',
#    'samples': ['daily',
#     'start daily',
#     'show me the report',
#     'I want the daily report']},
#   {'name': 'resetdaily',
#    'samples': ['reset', 'reset daily', 'reset daily status']},
#   {'name': 'dailystatus',
#    'samples': ['daily status',
#     'what is the daily status',
#     'I want the daily status']},
#   {'name': 'snooze',
#    'samples': ['snooze', 'snooze daily', 'increase snooze', 'snooze_daily']},
#   {'name': 'skipdaily',
#    'samples': ['skip', 'skip daily', 'skip daily', 'skip the daily report']},
#   {'name': 'report', 'samples': ['report', 'reports']},
#   {'name': 'kudos', 'samples': ['kudos', 'kudos back', 'kudos plus']},
#   {'name': 'meeting', 'samples': ['meeting']},
#   {'name': 'meeting status',
#    'samples': ['show meetings',
#     'meeting status',
#     'appointments status',
#     'meetings status',
#     'show appointments']}]}

# %%
# Create a list of tuples that assigns a list of words to an intent in English
words_en = []
labels_en = []
documents_en = []
punc_en = ['?', '!', ',', '.']

for intent in intents_en['intent']: 
    for sample in intent['samples']:
        word_list_en = nltk.word_tokenize(sample)
        words_en.extend(word_list_en)
        documents_en.append((word_list_en, intent['name']))
        if intent['name'] not in labels_en:
            labels_en.append(intent['name'])

# %%
# Create a list of tuples that assigns a list of words to an intent in Spanish
words_es = []
labels_es = []
documents_es = []
punc_es = ['?', '!', ',', '.']

for intent in intents_es['intent']: 
    for sample in intent['samples']:
        word_list_es = nltk.word_tokenize(sample)
        words_es.extend(word_list_es)
        documents_es.append((word_list_es, intent['name']))
        if intent['name'] not in labels_es:
            labels_es.append(intent['name'])

# %% [markdown]
# ## Bag of Words

# %%
# import NLP library
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()

# %%
# turn words to lower case and to base form
words_en = [lem.lemmatize(word.lower()) for word in words_en if word not in punc_en]
words_es = [lem.lemmatize(word.lower()) for word in words_es if word not in punc_es]


# sort words and remove duplicates in English
words_en = sorted(set(words_en))
labels_en = sorted(set(labels_en))

# sort words and remove duplicates in Spanish
words_es = sorted(set(words_es))
labels_es = sorted(set(labels_es))

# %% [markdown]
# ## Preprocessing input and output data

# %%
# create training and output arrays in English
training_en = []
output_empty_en = [0] * len(labels_en)
for document in documents_en:
    bag_en = []
    word_patterns_en = document[0]
    word_patterns_en = [lem.lemmatize(word.lower()) for word in word_patterns_en]
    for word in words_en:
        if word in word_patterns_en:
            bag_en.append(1)
        else:
            bag_en.append(0)
            
    # copy output list
    output_en = list(output_empty_en)
    output_en[labels_en.index(document[1])] = 1
    training_en.append([bag_en, output_en])

# %%
# create training and output arrays in Spanish
training_es = []
output_empty_es = [0] * len(labels_es)
for document in documents_es:
    bag_es = []
    word_patterns_es = document[0]
    word_patterns_es = [lem.lemmatize(word.lower()) for word in word_patterns_es]
    for word in words_es:
        if word in word_patterns_es:
            bag_es.append(1)
        else:
            bag_es.append(0)
            
    # copy output list
    output_es = list(output_empty_es)
    output_es[labels_es.index(document[1])] = 1
    training_es.append([bag_es, output_es])

# %%
# randomizing the order of the training data in English
random.shuffle(training_en)
training_en = np.array(training_en)

train_x_en = list(training_en[:,0])
train_y_en = list(training_en[:,1])

# randomizing the order of the training data in Spanish
random.shuffle(training_es)
training_es = np.array(training_es)

train_x_es = list(training_es[:,0])
train_y_es = list(training_es[:,1])
# Out:
# C:\Users\aashi\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\aashi\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ## Build Model

# %%
def model_en():
    model = Sequential()
    model.add(Dense(128, input_shape=(len(train_x_en[0]),), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(train_y_en[0]), activation='softmax'))
    return model


def model_es():
    model = Sequential()
    model.add(Dense(128, input_shape=(len(train_x_es[0]),), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(train_y_es[0]), activation='softmax'))
    return model

# %% [markdown]
# ### Train English Model

# %%
model_en = model_en()

optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_en.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
checkpoint_en = ModelCheckpoint(filepath='model_en.h5', monitor='acc')
model_en.fit(np.array(train_x_en), np.array(train_y_en), epochs=500, batch_size=5, verbose=1, callbacks=[checkpoint_en])
# Out:
# Epoch 1/500
# 93/93 [==============================] - 0s 4ms/sample - loss: 3.1912 - acc: 0.0968
# Epoch 2/500
# 93/93 [==============================] - 0s 279us/sample - loss: 3.1380 - acc: 0.0753
# Epoch 3/500
# 93/93 [==============================] - 0s 300us/sample - loss: 3.0186 - acc: 0.1398
# Epoch 4/500
# 93/93 [==============================] - 0s 279us/sample - loss: 2.9592 - acc: 0.1398
# Epoch 5/500
# 93/93 [==============================] - 0s 300us/sample - loss: 2.8943 - acc: 0.1505
# Epoch 6/500
# 93/93 [==============================] - 0s 343us/sample - loss: 2.8309 - acc: 0.1720
# Epoch 7/500
# 93/93 [==============================] - 0s 290us/sample - loss: 2.6477 - acc: 0.2581
# Epoch 8/500
# 93/93 [==============================] - 0s 365us/sample - loss: 2.4833 - acc: 0.3226
# Epoch 9/500
# 93/93 [==============================] - 0s 322us/sample - loss: 2.4573 - acc: 0.3333
# Epoch 10/500
# 93/93 [==============================] - 0s 311us/sample - loss: 2.4163 - acc: 0.3118
# Epoch 11/500
# 93/93 [==============================] - 0s 279us/sample - loss: 2.0964 - acc: 0.4086
# Epoch 12/500
# 93/93 [==============================] - 0s 290us/sample - loss: 2.0701 - acc: 0.4086
# Epoch 13/500
# 93/93 [==============================] - 0s 311us/sample - loss: 1.8020 - acc: 0.4731
# Epoch 14/500
# 93/93 [==============================] - 0s 322us/sample - loss: 1.7284 - acc: 0.5376
# Epoch 15/500
# 93/93 [==============================] - 0s 268us/sample - loss: 1.6331 - acc: 0.5376
# Epoch 16/500
# 93/93 [==============================] - 0s 322us/sample - loss: 1.5300 - acc: 0.5699
# Epoch 17/500
# 93/93 [==============================] - 0s 332us/sample - loss: 1.3675 - acc: 0.6989
# Epoch 18/500
# 93/93 [==============================] - 0s 322us/sample - loss: 1.2444 - acc: 0.6882
# Epoch 19/500
# 93/93 [==============================] - 0s 290us/sample - loss: 1.1187 - acc: 0.7097
# Epoch 20/500
# 93/93 [==============================] - 0s 322us/sample - loss: 1.1080 - acc: 0.7097
# Epoch 21/500
# 93/93 [==============================] - 0s 279us/sample - loss: 1.0827 - acc: 0.6989
# Epoch 22/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.8953 - acc: 0.7527
# Epoch 23/500
# 93/93 [==============================] - 0s 289us/sample - loss: 0.9876 - acc: 0.7312
# Epoch 24/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.9015 - acc: 0.7527
# Epoch 25/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.8306 - acc: 0.7419
# Epoch 26/500
# 93/93 [==============================] - 0s 311us/sample - loss: 0.7610 - acc: 0.8280
# Epoch 27/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.7680 - acc: 0.7849
# Epoch 28/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.6414 - acc: 0.8817
# Epoch 29/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.5940 - acc: 0.8065
# Epoch 30/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.5680 - acc: 0.8602
# Epoch 31/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.5100 - acc: 0.8602
# Epoch 32/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.4523 - acc: 0.8925
# Epoch 33/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.4839 - acc: 0.9140
# Epoch 34/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.4268 - acc: 0.8925
# Epoch 35/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.4740 - acc: 0.8495
# Epoch 36/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.4952 - acc: 0.8710
# Epoch 37/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.4661 - acc: 0.8710
# Epoch 38/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.4212 - acc: 0.8710
# Epoch 39/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.4253 - acc: 0.8817
# Epoch 40/500
# 93/93 [==============================] - 0s 311us/sample - loss: 0.4126 - acc: 0.8817
# Epoch 41/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.3810 - acc: 0.9032
# Epoch 42/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.3565 - acc: 0.9355
# Epoch 43/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.3642 - acc: 0.9032
# Epoch 44/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.3364 - acc: 0.9032
# Epoch 45/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.3278 - acc: 0.9140
# Epoch 46/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.3713 - acc: 0.9032
# Epoch 47/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.2802 - acc: 0.9355
# Epoch 48/500
# 93/93 [==============================] - 0s 365us/sample - loss: 0.3021 - acc: 0.9032
# Epoch 49/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2725 - acc: 0.8710
# Epoch 50/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2863 - acc: 0.9355
# Epoch 51/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.2355 - acc: 0.9462
# Epoch 52/500
# 93/93 [==============================] - 0s 300us/sample - loss: 0.3056 - acc: 0.9140
# Epoch 53/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2346 - acc: 0.9677
# Epoch 54/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.2887 - acc: 0.9032
# Epoch 55/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1535 - acc: 0.9892
# Epoch 56/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.3211 - acc: 0.9032
# Epoch 57/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2485 - acc: 0.9247
# Epoch 58/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1347 - acc: 0.9677
# Epoch 59/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2783 - acc: 0.9140
# Epoch 60/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2224 - acc: 0.9247
# Epoch 61/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1709 - acc: 0.9570
# Epoch 62/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2040 - acc: 0.9462
# Epoch 63/500
# 93/93 [==============================] - 0s 262us/sample - loss: 0.2284 - acc: 0.9355
# Epoch 64/500
# 93/93 [==============================] - 0s 250us/sample - loss: 0.2357 - acc: 0.9355
# Epoch 65/500
# 93/93 [==============================] - 0s 260us/sample - loss: 0.1900 - acc: 0.9462
# Epoch 66/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1635 - acc: 0.9677
# Epoch 67/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2022 - acc: 0.9032
# Epoch 68/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2681 - acc: 0.9247
# Epoch 69/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.2014 - acc: 0.9570
# Epoch 70/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1678 - acc: 0.9677
# Epoch 71/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1677 - acc: 0.9677
# Epoch 72/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1783 - acc: 0.9570
# Epoch 73/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2961 - acc: 0.9140
# Epoch 74/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.2013 - acc: 0.9140
# Epoch 75/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1242 - acc: 0.9677
# Epoch 76/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1329 - acc: 0.9785
# Epoch 77/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1728 - acc: 0.9462
# Epoch 78/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.1918 - acc: 0.9355
# Epoch 79/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1854 - acc: 0.9570
# Epoch 80/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1030 - acc: 0.9892
# Epoch 81/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1676 - acc: 0.9677
# Epoch 82/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1687 - acc: 0.9570
# Epoch 83/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1799 - acc: 0.9570
# Epoch 84/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1426 - acc: 0.9677
# Epoch 85/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1377 - acc: 0.9785
# Epoch 86/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1427 - acc: 0.9677
# Epoch 87/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.1370 - acc: 0.9677
# Epoch 88/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1231 - acc: 0.9892
# Epoch 89/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1268 - acc: 0.9570
# Epoch 90/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2473 - acc: 0.9355
# Epoch 91/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1646 - acc: 0.9570
# Epoch 92/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1170 - acc: 0.9570
# Epoch 93/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1054 - acc: 1.0000
# Epoch 94/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1045 - acc: 0.9570
# Epoch 95/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.1342 - acc: 0.9785
# Epoch 96/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1506 - acc: 0.9462
# Epoch 97/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1942 - acc: 0.9355
# Epoch 98/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1225 - acc: 0.9570
# Epoch 99/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.1553 - acc: 0.9462
# Epoch 100/500
# 93/93 [==============================] - 0s 322us/sample - loss: 0.0967 - acc: 0.9785
# Epoch 101/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0974 - acc: 0.9785
# Epoch 102/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1174 - acc: 0.9570
# Epoch 103/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1263 - acc: 0.9570
# Epoch 104/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1509 - acc: 0.9570
# Epoch 105/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1232 - acc: 0.9570
# Epoch 106/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1373 - acc: 0.9677
# Epoch 107/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1846 - acc: 0.9032
# Epoch 108/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1826 - acc: 0.9462
# Epoch 109/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1141 - acc: 0.9570
# Epoch 110/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1372 - acc: 0.9785
# Epoch 111/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0793 - acc: 0.9785
# Epoch 112/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1369 - acc: 0.9570
# Epoch 113/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.2107 - acc: 0.9247
# Epoch 114/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0867 - acc: 1.0000
# Epoch 115/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0900 - acc: 0.9892
# Epoch 116/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1444 - acc: 0.9462
# Epoch 117/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0902 - acc: 0.9785
# Epoch 118/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.1803 - acc: 0.9462
# Epoch 119/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1060 - acc: 0.9785
# Epoch 120/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0680 - acc: 0.9892
# Epoch 121/500
# 93/93 [==============================] - 0s 258us/sample - loss: 0.1049 - acc: 0.9785
# Epoch 122/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0844 - acc: 0.9785
# Epoch 123/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0714 - acc: 0.9785
# Epoch 124/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1280 - acc: 0.9785
# Epoch 125/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0859 - acc: 0.9785
# Epoch 126/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0869 - acc: 0.9892
# Epoch 127/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0898 - acc: 0.9785
# Epoch 128/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1150 - acc: 0.9677
# Epoch 129/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0806 - acc: 0.9677
# Epoch 130/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1300 - acc: 0.9785
# Epoch 131/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1103 - acc: 0.9677
# Epoch 132/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0898 - acc: 0.9677
# Epoch 133/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1337 - acc: 0.9570
# Epoch 134/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1070 - acc: 0.9677
# Epoch 135/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0705 - acc: 0.9785
# Epoch 136/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0640 - acc: 0.9892
# Epoch 137/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0445 - acc: 0.9892
# Epoch 138/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1550 - acc: 0.9462
# Epoch 139/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0744 - acc: 0.9677
# Epoch 140/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0625 - acc: 0.9892
# Epoch 141/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1322 - acc: 0.9570
# Epoch 142/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0733 - acc: 0.9785
# Epoch 143/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1430 - acc: 0.9677
# Epoch 144/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0657 - acc: 1.0000
# Epoch 145/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1491 - acc: 0.9677
# Epoch 146/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0913 - acc: 0.9677
# Epoch 147/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1171 - acc: 0.9570
# Epoch 148/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0888 - acc: 0.9785
# Epoch 149/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.1148 - acc: 0.9570
# Epoch 150/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0975 - acc: 0.9570
# Epoch 151/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0778 - acc: 0.9785
# Epoch 152/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1077 - acc: 0.9677
# Epoch 153/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0527 - acc: 0.9892
# Epoch 154/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1120 - acc: 0.9570
# Epoch 155/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0800 - acc: 0.9570
# Epoch 156/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0733 - acc: 0.9785
# Epoch 157/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0822 - acc: 0.9785
# Epoch 158/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0668 - acc: 0.9785
# Epoch 159/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1025 - acc: 0.9570
# Epoch 160/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0968 - acc: 0.9570
# Epoch 161/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0649 - acc: 0.9892
# Epoch 162/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0650 - acc: 0.9785
# Epoch 163/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0723 - acc: 0.9892
# Epoch 164/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0496 - acc: 0.9892
# Epoch 165/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0796 - acc: 0.9785
# Epoch 166/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0473 - acc: 1.0000
# Epoch 167/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0490 - acc: 1.0000
# Epoch 168/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0836 - acc: 0.9892
# Epoch 169/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0326 - acc: 1.0000
# Epoch 170/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0499 - acc: 0.9892
# Epoch 171/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0674 - acc: 0.9892
# Epoch 172/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0560 - acc: 0.9892
# Epoch 173/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0652 - acc: 0.9892
# Epoch 174/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0414 - acc: 0.9785
# Epoch 175/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0536 - acc: 0.9785
# Epoch 176/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0413 - acc: 0.9892
# Epoch 177/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0801 - acc: 0.9677
# Epoch 178/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0581 - acc: 0.9785
# Epoch 179/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0684 - acc: 0.9785
# Epoch 180/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0442 - acc: 0.9892
# Epoch 181/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0628 - acc: 0.9785
# Epoch 182/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1510 - acc: 0.9247
# Epoch 183/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0575 - acc: 0.9785
# Epoch 184/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0502 - acc: 0.9785
# Epoch 185/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0943 - acc: 0.9785
# Epoch 186/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1442 - acc: 0.9570
# Epoch 187/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0976 - acc: 0.9677
# Epoch 188/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0419 - acc: 0.9892
# Epoch 189/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0692 - acc: 0.9785
# Epoch 190/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1551 - acc: 0.9355
# Epoch 191/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0581 - acc: 0.9785
# Epoch 192/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0575 - acc: 1.0000
# Epoch 193/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0640 - acc: 0.9677
# Epoch 194/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1059 - acc: 0.9677
# Epoch 195/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0411 - acc: 0.9892
# Epoch 196/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1291 - acc: 0.9355
# Epoch 197/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0382 - acc: 0.9892
# Epoch 198/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0911 - acc: 0.9892
# Epoch 199/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1136 - acc: 0.9677
# Epoch 200/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1252 - acc: 0.9677
# Epoch 201/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0429 - acc: 0.9892
# Epoch 202/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0549 - acc: 0.9892
# Epoch 203/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1075 - acc: 0.9677
# Epoch 204/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0726 - acc: 0.9677
# Epoch 205/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0389 - acc: 0.9892
# Epoch 206/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0991 - acc: 0.9570
# Epoch 207/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0680 - acc: 0.9892
# Epoch 208/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0841 - acc: 0.9785
# Epoch 209/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1013 - acc: 0.9570
# Epoch 210/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0802 - acc: 0.9677
# Epoch 211/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0692 - acc: 0.9677
# Epoch 212/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0809 - acc: 0.9677
# Epoch 213/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0882 - acc: 0.9785
# Epoch 214/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0488 - acc: 0.9892
# Epoch 215/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0298 - acc: 1.0000
# Epoch 216/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0860 - acc: 0.9785
# Epoch 217/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1210 - acc: 0.9462
# Epoch 218/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0474 - acc: 0.9892
# Epoch 219/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0853 - acc: 0.9677
# Epoch 220/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0522 - acc: 0.9892
# Epoch 221/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0866 - acc: 0.9785
# Epoch 222/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0457 - acc: 0.9892
# Epoch 223/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0669 - acc: 0.9785
# Epoch 224/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0290 - acc: 0.9892
# Epoch 225/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0830 - acc: 0.9677
# Epoch 226/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0228 - acc: 0.9892
# Epoch 227/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0448 - acc: 0.9892
# Epoch 228/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0374 - acc: 0.9892
# Epoch 229/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0510 - acc: 0.9785
# Epoch 230/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0264 - acc: 1.0000
# Epoch 231/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0445 - acc: 0.9785
# Epoch 232/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1419 - acc: 0.9570
# Epoch 233/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0430 - acc: 0.9892
# Epoch 234/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0451 - acc: 1.0000
# Epoch 235/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0519 - acc: 0.9785
# Epoch 236/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0835 - acc: 0.9677
# Epoch 237/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0538 - acc: 0.9785
# Epoch 238/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0633 - acc: 0.9785
# Epoch 239/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0467 - acc: 0.9892
# Epoch 240/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0711 - acc: 0.9677
# Epoch 241/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0473 - acc: 0.9892
# Epoch 242/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0339 - acc: 0.9892
# Epoch 243/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0848 - acc: 0.9677
# Epoch 244/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0637 - acc: 0.9892
# Epoch 245/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0469 - acc: 1.0000
# Epoch 246/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0662 - acc: 0.9892
# Epoch 247/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0866 - acc: 0.9677
# Epoch 248/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0696 - acc: 0.9785
# Epoch 249/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0311 - acc: 1.0000
# Epoch 250/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0503 - acc: 0.9892
# Epoch 251/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1339 - acc: 0.9462
# Epoch 252/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0518 - acc: 0.9785
# Epoch 253/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0394 - acc: 1.0000
# Epoch 254/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0893 - acc: 0.9570
# Epoch 255/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0726 - acc: 0.9892
# Epoch 256/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0229 - acc: 0.9892
# Epoch 257/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0310 - acc: 0.9892
# Epoch 258/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0443 - acc: 0.9892
# Epoch 259/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0327 - acc: 0.9892
# Epoch 260/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0418 - acc: 0.9892
# Epoch 261/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0398 - acc: 0.9892
# Epoch 262/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0248 - acc: 1.0000
# Epoch 263/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0577 - acc: 0.9892
# Epoch 264/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0478 - acc: 1.0000
# Epoch 265/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0489 - acc: 0.9785
# Epoch 266/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0558 - acc: 0.9785
# Epoch 267/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0182 - acc: 1.0000
# Epoch 268/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1258 - acc: 0.9570
# Epoch 269/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0317 - acc: 0.9892
# Epoch 270/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0300 - acc: 0.9892
# Epoch 271/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0394 - acc: 1.0000
# Epoch 272/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1260 - acc: 0.9785
# Epoch 273/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0681 - acc: 0.9785
# Epoch 274/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0303 - acc: 0.9892
# Epoch 275/500
# 93/93 [==============================] - 0s 258us/sample - loss: 0.0252 - acc: 1.0000
# Epoch 276/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0903 - acc: 0.9785
# Epoch 277/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0156 - acc: 1.0000
# Epoch 278/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0561 - acc: 0.9785
# Epoch 279/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0222 - acc: 1.0000
# Epoch 280/500
# 93/93 [==============================] - ETA: 0s - loss: 4.7078e-04 - acc: 1.000 - 0s 257us/sample - loss: 0.0480 - acc: 0.9892
# Epoch 281/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0341 - acc: 1.0000
# Epoch 282/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0552 - acc: 0.9785
# Epoch 283/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0354 - acc: 0.9892
# Epoch 284/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0481 - acc: 0.9892
# Epoch 285/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0411 - acc: 0.9892
# Epoch 286/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0534 - acc: 0.9785
# Epoch 287/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0322 - acc: 0.9892
# Epoch 288/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0586 - acc: 0.9785
# Epoch 289/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0444 - acc: 0.9892
# Epoch 290/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0648 - acc: 0.9892
# Epoch 291/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0558 - acc: 0.9785
# Epoch 292/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0784 - acc: 0.9677
# Epoch 293/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0175 - acc: 1.0000
# Epoch 294/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0163 - acc: 1.0000
# Epoch 295/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0757 - acc: 0.9462
# Epoch 296/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1286 - acc: 0.9677
# Epoch 297/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0247 - acc: 1.0000
# Epoch 298/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0314 - acc: 1.0000
# Epoch 299/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0385 - acc: 0.9892
# Epoch 300/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0334 - acc: 0.9892
# Epoch 301/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0328 - acc: 1.0000
# Epoch 302/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0418 - acc: 0.9892
# Epoch 303/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1311 - acc: 0.9355
# Epoch 304/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0880 - acc: 0.9677
# Epoch 305/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0468 - acc: 0.9892
# Epoch 306/500
# 93/93 [==============================] - 0s 300us/sample - loss: 0.0203 - acc: 1.0000
# Epoch 307/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0426 - acc: 0.9892
# Epoch 308/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0199 - acc: 1.0000
# Epoch 309/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0463 - acc: 0.9892
# Epoch 310/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0906 - acc: 0.9677
# Epoch 311/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0193 - acc: 1.0000
# Epoch 312/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0738 - acc: 0.9892
# Epoch 313/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0278 - acc: 1.0000
# Epoch 314/500
# 93/93 [==============================] - 0s 258us/sample - loss: 0.0110 - acc: 1.0000
# Epoch 315/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0187 - acc: 1.0000
# Epoch 316/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0667 - acc: 0.9785
# Epoch 317/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0782 - acc: 0.9677
# Epoch 318/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0373 - acc: 0.9892
# Epoch 319/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0560 - acc: 0.9892
# Epoch 320/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0582 - acc: 0.9677
# Epoch 321/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0313 - acc: 0.9892
# Epoch 322/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0307 - acc: 1.0000
# Epoch 323/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0331 - acc: 0.9892
# Epoch 324/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0395 - acc: 0.9892
# Epoch 325/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0242 - acc: 1.0000
# Epoch 326/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0183 - acc: 1.0000
# Epoch 327/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0812 - acc: 0.9892
# Epoch 328/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0240 - acc: 1.0000
# Epoch 329/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0230 - acc: 1.0000
# Epoch 330/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0416 - acc: 0.9892
# Epoch 331/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1101 - acc: 0.9785
# Epoch 332/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0427 - acc: 0.9892
# Epoch 333/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0493 - acc: 0.9892
# Epoch 334/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0373 - acc: 0.9785
# Epoch 335/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0326 - acc: 0.9892
# Epoch 336/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0285 - acc: 0.9892
# Epoch 337/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0168 - acc: 1.0000
# Epoch 338/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0276 - acc: 0.9892
# Epoch 339/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0580 - acc: 0.9785
# Epoch 340/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0164 - acc: 1.0000
# Epoch 341/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0218 - acc: 1.0000
# Epoch 342/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0328 - acc: 0.9892
# Epoch 343/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0164 - acc: 1.0000
# Epoch 344/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.1045 - acc: 0.9785
# Epoch 345/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0368 - acc: 0.9785
# Epoch 346/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0470 - acc: 0.9892
# Epoch 347/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0308 - acc: 1.0000
# Epoch 348/500
# 93/93 [==============================] - 0s 365us/sample - loss: 0.0776 - acc: 0.9785
# Epoch 349/500
# 93/93 [==============================] - 0s 397us/sample - loss: 0.0241 - acc: 1.0000
# Epoch 350/500
# 93/93 [==============================] - 0s 332us/sample - loss: 0.0081 - acc: 1.0000
# Epoch 351/500
# 93/93 [==============================] - 0s 322us/sample - loss: 0.0331 - acc: 0.9892
# Epoch 352/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0164 - acc: 0.9892
# Epoch 353/500
# 93/93 [==============================] - 0s 311us/sample - loss: 0.0708 - acc: 0.9677
# Epoch 354/500
# 93/93 [==============================] - 0s 300us/sample - loss: 0.0032 - acc: 1.0000
# Epoch 355/500
# 93/93 [==============================] - 0s 343us/sample - loss: 0.0403 - acc: 0.9892
# Epoch 356/500
# 93/93 [==============================] - 0s 322us/sample - loss: 0.0290 - acc: 0.9892
# Epoch 357/500
# 93/93 [==============================] - 0s 322us/sample - loss: 0.0282 - acc: 1.0000
# Epoch 358/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0252 - acc: 1.0000
# Epoch 359/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0668 - acc: 0.9785
# Epoch 360/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0286 - acc: 0.9892
# Epoch 361/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0292 - acc: 0.9892
# Epoch 362/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0058 - acc: 1.0000
# Epoch 363/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0561 - acc: 0.9892
# Epoch 364/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0703 - acc: 0.9785
# Epoch 365/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0527 - acc: 0.9892
# Epoch 366/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0439 - acc: 0.9892
# Epoch 367/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0741 - acc: 0.9785
# Epoch 368/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0228 - acc: 1.0000
# Epoch 369/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0301 - acc: 0.9785
# Epoch 370/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0819 - acc: 0.9785
# Epoch 371/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0685 - acc: 0.9892
# Epoch 372/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0202 - acc: 1.0000
# Epoch 373/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0290 - acc: 0.9892
# Epoch 374/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0249 - acc: 1.0000
# Epoch 375/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0332 - acc: 0.9892
# Epoch 376/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0808 - acc: 0.9677
# Epoch 377/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0312 - acc: 0.9892
# Epoch 378/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0219 - acc: 1.0000
# Epoch 379/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0364 - acc: 0.9785
# Epoch 380/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0158 - acc: 1.0000
# Epoch 381/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0321 - acc: 0.9892
# Epoch 382/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0698 - acc: 0.9677
# Epoch 383/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0472 - acc: 1.0000
# Epoch 384/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0401 - acc: 0.9785
# Epoch 385/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0385 - acc: 0.9892
# Epoch 386/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0413 - acc: 0.9892
# Epoch 387/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0064 - acc: 1.0000
# Epoch 388/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0389 - acc: 0.9892
# Epoch 389/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0692 - acc: 0.9677
# Epoch 390/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0269 - acc: 1.0000
# Epoch 391/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0668 - acc: 0.9785
# Epoch 392/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0747 - acc: 0.9785
# Epoch 393/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0216 - acc: 1.0000
# Epoch 394/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0465 - acc: 0.9892
# Epoch 395/500
# 93/93 [==============================] - 0s 225us/sample - loss: 0.0440 - acc: 0.9785
# Epoch 396/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0780 - acc: 0.9785
# Epoch 397/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0224 - acc: 1.0000
# Epoch 398/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0234 - acc: 1.0000
# Epoch 399/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0148 - acc: 1.0000
# Epoch 400/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0559 - acc: 0.9785
# Epoch 401/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0378 - acc: 0.9785
# Epoch 402/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0216 - acc: 1.0000
# Epoch 403/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0286 - acc: 1.0000
# Epoch 404/500
# 93/93 [==============================] - 0s 235us/sample - loss: 0.0418 - acc: 0.9892
# Epoch 405/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0112 - acc: 1.0000
# Epoch 406/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0187 - acc: 1.0000
# Epoch 407/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0168 - acc: 1.0000
# Epoch 408/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0572 - acc: 0.9785
# Epoch 409/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0212 - acc: 0.9892
# Epoch 410/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0468 - acc: 0.9892
# Epoch 411/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0214 - acc: 1.0000
# Epoch 412/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0149 - acc: 1.0000
# Epoch 413/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0108 - acc: 1.0000
# Epoch 414/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0352 - acc: 0.9892
# Epoch 415/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0761 - acc: 0.9785
# Epoch 416/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0927 - acc: 0.9785
# Epoch 417/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0391 - acc: 0.9785
# Epoch 418/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0442 - acc: 0.9892
# Epoch 419/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0157 - acc: 1.0000
# Epoch 420/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0151 - acc: 1.0000
# Epoch 421/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0199 - acc: 1.0000
# Epoch 422/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0529 - acc: 0.9677
# Epoch 423/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0324 - acc: 0.9892
# Epoch 424/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0176 - acc: 1.0000
# Epoch 425/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0471 - acc: 0.9892
# Epoch 426/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0148 - acc: 1.0000
# Epoch 427/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0196 - acc: 0.9892
# Epoch 428/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0256 - acc: 0.9892
# Epoch 429/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0466 - acc: 0.9785
# Epoch 430/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0812 - acc: 0.9785
# Epoch 431/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0112 - acc: 1.0000
# Epoch 432/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0212 - acc: 1.0000
# Epoch 433/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0316 - acc: 1.0000
# Epoch 434/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0407 - acc: 0.9892
# Epoch 435/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0788 - acc: 0.9785
# Epoch 436/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0260 - acc: 0.9892
# Epoch 437/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0280 - acc: 1.0000
# Epoch 438/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0185 - acc: 1.0000
# Epoch 439/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0856 - acc: 0.9677
# Epoch 440/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0365 - acc: 0.9892
# Epoch 441/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.1128 - acc: 0.9677
# Epoch 442/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0195 - acc: 0.9892
# Epoch 443/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0299 - acc: 0.9892
# Epoch 444/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0434 - acc: 0.9892
# Epoch 445/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0351 - acc: 0.9892
# Epoch 446/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0591 - acc: 0.9892
# Epoch 447/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0077 - acc: 1.0000
# Epoch 448/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0168 - acc: 1.0000
# Epoch 449/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0728 - acc: 0.9677
# Epoch 450/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0544 - acc: 0.9785
# Epoch 451/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0099 - acc: 1.0000
# Epoch 452/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0681 - acc: 0.9570
# Epoch 453/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0674 - acc: 0.9677
# Epoch 454/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.1172 - acc: 0.9677
# Epoch 455/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0371 - acc: 0.9892
# Epoch 456/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.1010 - acc: 0.9677
# Epoch 457/500
# 93/93 [==============================] - 0s 268us/sample - loss: 0.0967 - acc: 0.9785
# Epoch 458/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0390 - acc: 0.9892
# Epoch 459/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0821 - acc: 0.9570
# Epoch 460/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0323 - acc: 0.9892
# Epoch 461/500
# 93/93 [==============================] - 0s 246us/sample - loss: 0.0277 - acc: 0.9892
# Epoch 462/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0166 - acc: 1.0000
# Epoch 463/500
# 93/93 [==============================] - 0s 418us/sample - loss: 0.0507 - acc: 0.9892
# Epoch 464/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0126 - acc: 1.0000
# Epoch 465/500
# 93/93 [==============================] - 0s 354us/sample - loss: 0.0441 - acc: 0.9892
# Epoch 466/500
# 93/93 [==============================] - 0s 365us/sample - loss: 0.0240 - acc: 1.0000
# Epoch 467/500
# 93/93 [==============================] - 0s 365us/sample - loss: 0.0102 - acc: 1.0000
# Epoch 468/500
# 93/93 [==============================] - 0s 386us/sample - loss: 0.0506 - acc: 1.0000
# Epoch 469/500
# 93/93 [==============================] - 0s 407us/sample - loss: 0.0320 - acc: 1.0000
# Epoch 470/500
# 93/93 [==============================] - 0s 318us/sample - loss: 0.0479 - acc: 0.9892
# Epoch 471/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0061 - acc: 1.0000
# Epoch 472/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0062 - acc: 1.0000
# Epoch 473/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0348 - acc: 0.9785
# Epoch 474/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0434 - acc: 0.9892
# Epoch 475/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0146 - acc: 1.0000
# Epoch 476/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0638 - acc: 0.9677
# Epoch 477/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0222 - acc: 1.0000
# Epoch 478/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0155 - acc: 1.0000
# Epoch 479/500
# 93/93 [==============================] - 0s 290us/sample - loss: 0.0149 - acc: 1.0000
# Epoch 480/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0194 - acc: 1.0000
# Epoch 481/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0317 - acc: 0.9785
# Epoch 482/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0575 - acc: 0.9677
# Epoch 483/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0318 - acc: 0.9785
# Epoch 484/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0210 - acc: 0.9892
# Epoch 485/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0448 - acc: 0.9892
# Epoch 486/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0076 - acc: 1.0000
# Epoch 487/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0355 - acc: 0.9892
# Epoch 488/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0300 - acc: 0.9892
# Epoch 489/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0563 - acc: 0.9892
# Epoch 490/500
# 93/93 [==============================] - 0s 300us/sample - loss: 0.0104 - acc: 1.0000
# Epoch 491/500
# 93/93 [==============================] - 0s 397us/sample - loss: 0.0428 - acc: 0.9892
# Epoch 492/500
# 93/93 [==============================] - 0s 354us/sample - loss: 0.0122 - acc: 1.0000
# Epoch 493/500
# 93/93 [==============================] - 0s 257us/sample - loss: 0.0354 - acc: 0.9892
# Epoch 494/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0294 - acc: 0.9892
# Epoch 495/500
# 93/93 [==============================] - 0s 236us/sample - loss: 0.0476 - acc: 0.9785
# Epoch 496/500
# 93/93 [==============================] - 0s 343us/sample - loss: 0.0186 - acc: 0.9892
# Epoch 497/500
# 93/93 [==============================] - 0s 279us/sample - loss: 0.0049 - acc: 1.0000
# Epoch 498/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0203 - acc: 1.0000
# Epoch 499/500
# 93/93 [==============================] - 0s 247us/sample - loss: 0.0129 - acc: 1.0000
# Epoch 500/500
# 93/93 [==============================] - 0s 332us/sample - loss: 0.0274 - acc: 0.9892

# %% [markdown]
# ### Train Spanish Model

# %%
model_es = model_es()

optimizer = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_es.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
checkpoint_es = ModelCheckpoint(filepath='model_es.h5', monitor='acc')
model_es.fit(np.array(train_x_es), np.array(train_y_es), epochs=500, batch_size=5, verbose=1, callbacks=[checkpoint_es])
# Out:
# Epoch 1/500
# 56/56 [==============================] - 0s 6ms/sample - loss: 3.1910 - acc: 0.0714
# Epoch 2/500
# 56/56 [==============================] - 0s 321us/sample - loss: 3.1556 - acc: 0.1071
# Epoch 3/500
# 56/56 [==============================] - 0s 338us/sample - loss: 3.0845 - acc: 0.0714
# Epoch 4/500
# 56/56 [==============================] - 0s 356us/sample - loss: 3.0521 - acc: 0.0893
# Epoch 5/500
# 56/56 [==============================] - 0s 338us/sample - loss: 2.9868 - acc: 0.1429
# Epoch 6/500
# 56/56 [==============================] - 0s 356us/sample - loss: 2.9334 - acc: 0.1250
# Epoch 7/500
# 56/56 [==============================] - 0s 321us/sample - loss: 2.9201 - acc: 0.1786
# Epoch 8/500
# 56/56 [==============================] - 0s 321us/sample - loss: 2.7960 - acc: 0.1429
# Epoch 9/500
# 56/56 [==============================] - 0s 338us/sample - loss: 2.8158 - acc: 0.1964
# Epoch 10/500
# 56/56 [==============================] - 0s 374us/sample - loss: 2.6340 - acc: 0.2143
# Epoch 11/500
# 56/56 [==============================] - 0s 338us/sample - loss: 2.5787 - acc: 0.2857
# Epoch 12/500
# 56/56 [==============================] - 0s 356us/sample - loss: 2.4180 - acc: 0.3750
# Epoch 13/500
# 56/56 [==============================] - 0s 338us/sample - loss: 2.4364 - acc: 0.4286
# Epoch 14/500
# 56/56 [==============================] - 0s 338us/sample - loss: 2.3135 - acc: 0.4107
# Epoch 15/500
# 56/56 [==============================] - 0s 392us/sample - loss: 2.2291 - acc: 0.3750
# Epoch 16/500
# 56/56 [==============================] - 0s 356us/sample - loss: 2.2198 - acc: 0.4286
# Epoch 17/500
# 56/56 [==============================] - 0s 481us/sample - loss: 1.9960 - acc: 0.4821
# Epoch 18/500
# 56/56 [==============================] - 0s 410us/sample - loss: 1.9923 - acc: 0.4643
# Epoch 19/500
# 56/56 [==============================] - 0s 338us/sample - loss: 1.9321 - acc: 0.5179
# Epoch 20/500
# 56/56 [==============================] - 0s 338us/sample - loss: 1.9703 - acc: 0.4821
# Epoch 21/500
# 56/56 [==============================] - 0s 356us/sample - loss: 1.8707 - acc: 0.4821
# Epoch 22/500
# 56/56 [==============================] - 0s 356us/sample - loss: 1.6701 - acc: 0.5536
# Epoch 23/500
# 56/56 [==============================] - 0s 338us/sample - loss: 1.7242 - acc: 0.5536
# Epoch 24/500
# 56/56 [==============================] - 0s 356us/sample - loss: 1.6252 - acc: 0.6071
# Epoch 25/500
# 56/56 [==============================] - 0s 356us/sample - loss: 1.5312 - acc: 0.6071
# Epoch 26/500
# 56/56 [==============================] - 0s 374us/sample - loss: 1.4949 - acc: 0.6071
# Epoch 27/500
# 56/56 [==============================] - 0s 516us/sample - loss: 1.5421 - acc: 0.5536
# Epoch 28/500
# 56/56 [==============================] - 0s 427us/sample - loss: 1.4603 - acc: 0.6429
# Epoch 29/500
# 56/56 [==============================] - 0s 516us/sample - loss: 1.2505 - acc: 0.6964
# Epoch 30/500
# 56/56 [==============================] - 0s 588us/sample - loss: 1.3169 - acc: 0.6607
# Epoch 31/500
# 56/56 [==============================] - 0s 890us/sample - loss: 1.0703 - acc: 0.7500
# Epoch 32/500
# 56/56 [==============================] - 0s 766us/sample - loss: 1.1234 - acc: 0.7143
# Epoch 33/500
# 56/56 [==============================] - 0s 392us/sample - loss: 1.2528 - acc: 0.6607
# Epoch 34/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.9194 - acc: 0.7500
# Epoch 35/500
# 56/56 [==============================] - 0s 392us/sample - loss: 1.0060 - acc: 0.7679
# Epoch 36/500
# 56/56 [==============================] - 0s 338us/sample - loss: 1.0563 - acc: 0.6964
# Epoch 37/500
# 56/56 [==============================] - 0s 445us/sample - loss: 1.1537 - acc: 0.6964
# Epoch 38/500
# 56/56 [==============================] - 0s 374us/sample - loss: 1.1535 - acc: 0.7143
# Epoch 39/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.9153 - acc: 0.7500
# Epoch 40/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.9722 - acc: 0.6786
# Epoch 41/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.9394 - acc: 0.7857
# Epoch 42/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.9509 - acc: 0.6786
# Epoch 43/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.8289 - acc: 0.7679
# Epoch 44/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.7147 - acc: 0.8036
# Epoch 45/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.7704 - acc: 0.7321
# Epoch 46/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.6743 - acc: 0.7857
# Epoch 47/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.6074 - acc: 0.8571
# Epoch 48/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.7103 - acc: 0.8214
# Epoch 49/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.8282 - acc: 0.7321
# Epoch 50/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.6520 - acc: 0.7857
# Epoch 51/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.6407 - acc: 0.7857
# Epoch 52/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.6796 - acc: 0.8571
# Epoch 53/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.5483 - acc: 0.8750
# Epoch 54/500
# 56/56 [==============================] - 0s 303us/sample - loss: 0.7200 - acc: 0.8214
# Epoch 55/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.4571 - acc: 0.8393
# Epoch 56/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.6283 - acc: 0.8036
# Epoch 57/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.4898 - acc: 0.8393
# Epoch 58/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.5075 - acc: 0.8750
# Epoch 59/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.5183 - acc: 0.8571
# Epoch 60/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.4729 - acc: 0.8571
# Epoch 61/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.5570 - acc: 0.8929
# Epoch 62/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.6186 - acc: 0.8393
# Epoch 63/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.4769 - acc: 0.8571
# Epoch 64/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.5311 - acc: 0.8393
# Epoch 65/500
# 56/56 [==============================] - 0s 303us/sample - loss: 0.4037 - acc: 0.8929
# Epoch 66/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.4745 - acc: 0.8571
# Epoch 67/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3778 - acc: 0.9286
# Epoch 68/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.5396 - acc: 0.8929
# Epoch 69/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3837 - acc: 0.8929
# Epoch 70/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2765 - acc: 0.9643
# Epoch 71/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3569 - acc: 0.8750
# Epoch 72/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3494 - acc: 0.8750
# Epoch 73/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3425 - acc: 0.8750
# Epoch 74/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.4228 - acc: 0.8393
# Epoch 75/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3830 - acc: 0.8929
# Epoch 76/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.4486 - acc: 0.8750
# Epoch 77/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3790 - acc: 0.8571
# Epoch 78/500
# 56/56 [==============================] - ETA: 0s - loss: 0.0333 - acc: 1.000 - 0s 321us/sample - loss: 0.4345 - acc: 0.8214
# Epoch 79/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3387 - acc: 0.9107
# Epoch 80/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3902 - acc: 0.8750
# Epoch 81/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2967 - acc: 0.8929
# Epoch 82/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3367 - acc: 0.9107
# Epoch 83/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.5352 - acc: 0.8393
# Epoch 84/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.4446 - acc: 0.8929
# Epoch 85/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3105 - acc: 0.9643
# Epoch 86/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3010 - acc: 0.9107
# Epoch 87/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3028 - acc: 0.9107
# Epoch 88/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2398 - acc: 0.9464
# Epoch 89/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2655 - acc: 0.9286
# Epoch 90/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.2762 - acc: 0.9107
# Epoch 91/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3329 - acc: 0.9107
# Epoch 92/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2524 - acc: 0.9107
# Epoch 93/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3074 - acc: 0.8750
# Epoch 94/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3037 - acc: 0.8750
# Epoch 95/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1265 - acc: 0.9821
# Epoch 96/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1722 - acc: 0.9643
# Epoch 97/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3746 - acc: 0.9107
# Epoch 98/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2387 - acc: 0.9286
# Epoch 99/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3627 - acc: 0.8750
# Epoch 100/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3590 - acc: 0.9107
# Epoch 101/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1745 - acc: 0.9821
# Epoch 102/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3142 - acc: 0.8929
# Epoch 103/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2002 - acc: 0.9107
# Epoch 104/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1922 - acc: 0.9821
# Epoch 105/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3045 - acc: 0.9107
# Epoch 106/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0987 - acc: 0.9821
# Epoch 107/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2510 - acc: 0.9107
# Epoch 108/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2196 - acc: 0.9286
# Epoch 109/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.3424 - acc: 0.9107
# Epoch 110/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1798 - acc: 0.9821
# Epoch 111/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1866 - acc: 0.9286
# Epoch 112/500
# 56/56 [==============================] - 0s 320us/sample - loss: 0.2225 - acc: 0.9107
# Epoch 113/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2627 - acc: 0.9107
# Epoch 114/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2631 - acc: 0.9107
# Epoch 115/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1743 - acc: 0.9643
# Epoch 116/500
# 56/56 [==============================] - 0s 303us/sample - loss: 0.2748 - acc: 0.9643
# Epoch 117/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2770 - acc: 0.9286
# Epoch 118/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2105 - acc: 0.9643
# Epoch 119/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2164 - acc: 0.9286
# Epoch 120/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2321 - acc: 0.9107
# Epoch 121/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2072 - acc: 0.9286
# Epoch 122/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1931 - acc: 0.9643
# Epoch 123/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1115 - acc: 0.9643
# Epoch 124/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.2193 - acc: 0.9107
# Epoch 125/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1840 - acc: 0.9821
# Epoch 126/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1439 - acc: 0.9643
# Epoch 127/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1815 - acc: 0.9643
# Epoch 128/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2128 - acc: 0.9464
# Epoch 129/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2436 - acc: 0.9286
# Epoch 130/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2326 - acc: 0.9107
# Epoch 131/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.2543 - acc: 0.9107
# Epoch 132/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2172 - acc: 0.9464
# Epoch 133/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1503 - acc: 0.9464
# Epoch 134/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0979 - acc: 1.0000
# Epoch 135/500
# 56/56 [==============================] - 0s 320us/sample - loss: 0.2237 - acc: 0.9107
# Epoch 136/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1757 - acc: 0.9643
# Epoch 137/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1308 - acc: 0.9643
# Epoch 138/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1865 - acc: 0.9643
# Epoch 139/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2004 - acc: 0.9464
# Epoch 140/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1401 - acc: 0.9643
# Epoch 141/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1674 - acc: 0.9643
# Epoch 142/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1507 - acc: 0.9464
# Epoch 143/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2518 - acc: 0.9107
# Epoch 144/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1719 - acc: 0.9286
# Epoch 145/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2212 - acc: 0.9286
# Epoch 146/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.3742 - acc: 0.8929
# Epoch 147/500
# 56/56 [==============================] - 0s 320us/sample - loss: 0.1318 - acc: 0.9821
# Epoch 148/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2114 - acc: 0.9464
# Epoch 149/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1832 - acc: 0.9643
# Epoch 150/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1437 - acc: 0.9821
# Epoch 151/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.2057 - acc: 0.9286
# Epoch 152/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1110 - acc: 0.9821
# Epoch 153/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1189 - acc: 0.9643
# Epoch 154/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.1565 - acc: 0.9464
# Epoch 155/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2172 - acc: 0.9107
# Epoch 156/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1389 - acc: 0.9464
# Epoch 157/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1256 - acc: 0.9643
# Epoch 158/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1808 - acc: 0.8929
# Epoch 159/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1475 - acc: 0.9643
# Epoch 160/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1468 - acc: 0.9643
# Epoch 161/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1601 - acc: 0.9643
# Epoch 162/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2536 - acc: 0.9107
# Epoch 163/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2653 - acc: 0.8929
# Epoch 164/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.3367 - acc: 0.8929
# Epoch 165/500
# 56/56 [==============================] - 0s 516us/sample - loss: 0.2944 - acc: 0.9107
# Epoch 166/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.2165 - acc: 0.9286
# Epoch 167/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1914 - acc: 0.9286
# Epoch 168/500
# 56/56 [==============================] - 0s 357us/sample - loss: 0.2849 - acc: 0.8571
# Epoch 169/500
# 56/56 [==============================] - 0s 363us/sample - loss: 0.2491 - acc: 0.9107
# Epoch 170/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.2906 - acc: 0.8750
# Epoch 171/500
# 56/56 [==============================] - 0s 345us/sample - loss: 0.2684 - acc: 0.8929
# Epoch 172/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1718 - acc: 0.9464
# Epoch 173/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1838 - acc: 0.9286
# Epoch 174/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2599 - acc: 0.9286
# Epoch 175/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1559 - acc: 0.9464
# Epoch 176/500
# 56/56 [==============================] - 0s 445us/sample - loss: 0.1748 - acc: 0.9464
# Epoch 177/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1881 - acc: 0.9286
# Epoch 178/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2187 - acc: 0.9464
# Epoch 179/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1737 - acc: 0.9643
# Epoch 180/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1413 - acc: 0.9643
# Epoch 181/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2206 - acc: 0.9286
# Epoch 182/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1593 - acc: 0.9286
# Epoch 183/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0777 - acc: 1.0000
# Epoch 184/500
# 56/56 [==============================] - 0s 481us/sample - loss: 0.0736 - acc: 1.0000
# Epoch 185/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.2030 - acc: 0.9107
# Epoch 186/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1041 - acc: 0.9643
# Epoch 187/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0737 - acc: 0.9821
# Epoch 188/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.2021 - acc: 0.9286
# Epoch 189/500
# 56/56 [==============================] - 0s 552us/sample - loss: 0.0738 - acc: 1.0000
# Epoch 190/500
# 56/56 [==============================] - 0s 516us/sample - loss: 0.1399 - acc: 0.9464
# Epoch 191/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.1036 - acc: 0.9643
# Epoch 192/500
# 56/56 [==============================] - 0s 819us/sample - loss: 0.2064 - acc: 0.9286
# Epoch 193/500
# 56/56 [==============================] - 0s 481us/sample - loss: 0.1804 - acc: 0.9286
# Epoch 194/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1593 - acc: 0.9464
# Epoch 195/500
# 56/56 [==============================] - 0s 445us/sample - loss: 0.1453 - acc: 0.9464
# Epoch 196/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1350 - acc: 0.9464
# Epoch 197/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1493 - acc: 0.9464
# Epoch 198/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2034 - acc: 0.9286
# Epoch 199/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2445 - acc: 0.9107
# Epoch 200/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1399 - acc: 0.9643
# Epoch 201/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1689 - acc: 0.9643
# Epoch 202/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0725 - acc: 0.9821
# Epoch 203/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1505 - acc: 0.9286
# Epoch 204/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1506 - acc: 0.9643
# Epoch 205/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1130 - acc: 0.9464
# Epoch 206/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0685 - acc: 0.9821
# Epoch 207/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2755 - acc: 0.8750
# Epoch 208/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0588 - acc: 0.9821
# Epoch 209/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1864 - acc: 0.9286
# Epoch 210/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0708 - acc: 0.9821
# Epoch 211/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1220 - acc: 0.9821
# Epoch 212/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0525 - acc: 0.9821
# Epoch 213/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2251 - acc: 0.9286
# Epoch 214/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0787 - acc: 0.9643
# Epoch 215/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1351 - acc: 0.9643
# Epoch 216/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0531 - acc: 0.9821
# Epoch 217/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1357 - acc: 0.9821
# Epoch 218/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1135 - acc: 0.9643
# Epoch 219/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1556 - acc: 0.9821
# Epoch 220/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1620 - acc: 0.9464
# Epoch 221/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.1141 - acc: 0.9821
# Epoch 222/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1108 - acc: 0.9821
# Epoch 223/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1705 - acc: 0.9464
# Epoch 224/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1767 - acc: 0.9643
# Epoch 225/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1796 - acc: 0.9643
# Epoch 226/500
# 56/56 [==============================] - 0s 320us/sample - loss: 0.1502 - acc: 0.9821
# Epoch 227/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1303 - acc: 0.9464
# Epoch 228/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2664 - acc: 0.8929
# Epoch 229/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0768 - acc: 0.9821
# Epoch 230/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0882 - acc: 0.9821
# Epoch 231/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1206 - acc: 0.9643
# Epoch 232/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.1699 - acc: 0.9643
# Epoch 233/500
# 56/56 [==============================] - 0s 481us/sample - loss: 0.1020 - acc: 0.9821
# Epoch 234/500
# 56/56 [==============================] - 0s 445us/sample - loss: 0.0693 - acc: 0.9643
# Epoch 235/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1737 - acc: 0.9286
# Epoch 236/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.2234 - acc: 0.9107
# Epoch 237/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1177 - acc: 0.9643
# Epoch 238/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.0569 - acc: 0.9821
# Epoch 239/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.1456 - acc: 0.9643
# Epoch 240/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1252 - acc: 0.9821
# Epoch 241/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.1877 - acc: 0.9643
# Epoch 242/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0861 - acc: 0.9643
# Epoch 243/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0723 - acc: 0.9821
# Epoch 244/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0976 - acc: 0.9643
# Epoch 245/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1439 - acc: 0.9464
# Epoch 246/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1200 - acc: 0.9643
# Epoch 247/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1476 - acc: 0.9643
# Epoch 248/500
# 56/56 [==============================] - 0s 445us/sample - loss: 0.1269 - acc: 0.9821
# Epoch 249/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1474 - acc: 0.9464
# Epoch 250/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1948 - acc: 0.9286
# Epoch 251/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.0966 - acc: 0.9821
# Epoch 252/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0455 - acc: 1.0000
# Epoch 253/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1069 - acc: 0.9643
# Epoch 254/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0823 - acc: 0.9643
# Epoch 255/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0751 - acc: 0.9821
# Epoch 256/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1352 - acc: 0.9464
# Epoch 257/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2032 - acc: 0.9107
# Epoch 258/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1326 - acc: 0.9464
# Epoch 259/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1154 - acc: 0.9464
# Epoch 260/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0919 - acc: 0.9643
# Epoch 261/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1192 - acc: 0.9643
# Epoch 262/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0881 - acc: 0.9643
# Epoch 263/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1573 - acc: 0.9464
# Epoch 264/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0545 - acc: 0.9821
# Epoch 265/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1439 - acc: 0.9286
# Epoch 266/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1617 - acc: 0.9286
# Epoch 267/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.2062 - acc: 0.9464
# Epoch 268/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0762 - acc: 0.9821
# Epoch 269/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1958 - acc: 0.9107
# Epoch 270/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.1458 - acc: 0.9464
# Epoch 271/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0780 - acc: 0.9821
# Epoch 272/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0813 - acc: 0.9643
# Epoch 273/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0770 - acc: 0.9643
# Epoch 274/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0725 - acc: 0.9821
# Epoch 275/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1065 - acc: 0.9464
# Epoch 276/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1308 - acc: 0.9464
# Epoch 277/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1315 - acc: 0.9464
# Epoch 278/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1562 - acc: 0.9286
# Epoch 279/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0841 - acc: 0.9643
# Epoch 280/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1504 - acc: 0.9464
# Epoch 281/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1095 - acc: 0.9643
# Epoch 282/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.1085 - acc: 0.9643
# Epoch 283/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1575 - acc: 0.9464
# Epoch 284/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1309 - acc: 0.9286
# Epoch 285/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1304 - acc: 0.9464
# Epoch 286/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1506 - acc: 0.9464
# Epoch 287/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0926 - acc: 0.9643
# Epoch 288/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0926 - acc: 0.9821
# Epoch 289/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0846 - acc: 0.9643
# Epoch 290/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1033 - acc: 0.9643
# Epoch 291/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1221 - acc: 0.9821
# Epoch 292/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0468 - acc: 0.9821
# Epoch 293/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1132 - acc: 0.9286
# Epoch 294/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0774 - acc: 0.9821
# Epoch 295/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0465 - acc: 1.0000
# Epoch 296/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0562 - acc: 0.9821
# Epoch 297/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1257 - acc: 0.9464
# Epoch 298/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1371 - acc: 0.9821
# Epoch 299/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1173 - acc: 0.9464
# Epoch 300/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1747 - acc: 0.9464
# Epoch 301/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0572 - acc: 1.0000
# Epoch 302/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0295 - acc: 0.9821
# Epoch 303/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0991 - acc: 0.9643
# Epoch 304/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1215 - acc: 0.9643
# Epoch 305/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1209 - acc: 0.9643
# Epoch 306/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0768 - acc: 0.9643
# Epoch 307/500
# 56/56 [==============================] - 0s 320us/sample - loss: 0.1667 - acc: 0.9107
# Epoch 308/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1915 - acc: 0.9464
# Epoch 309/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0981 - acc: 0.9821
# Epoch 310/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0818 - acc: 0.9643
# Epoch 311/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1346 - acc: 0.9643
# Epoch 312/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1309 - acc: 0.9464
# Epoch 313/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0832 - acc: 0.9643
# Epoch 314/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0649 - acc: 0.9821
# Epoch 315/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0748 - acc: 0.9821
# Epoch 316/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.2415 - acc: 0.9286
# Epoch 317/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0525 - acc: 0.9643
# Epoch 318/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0585 - acc: 0.9821
# Epoch 319/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0956 - acc: 0.9643
# Epoch 320/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.1323 - acc: 0.9643
# Epoch 321/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0367 - acc: 1.0000
# Epoch 322/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0763 - acc: 0.9821
# Epoch 323/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0982 - acc: 0.9643
# Epoch 324/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0918 - acc: 0.9643
# Epoch 325/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0802 - acc: 0.9821
# Epoch 326/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0798 - acc: 0.9643
# Epoch 327/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1077 - acc: 0.9821
# Epoch 328/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0974 - acc: 0.9821
# Epoch 329/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1124 - acc: 0.9821
# Epoch 330/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0683 - acc: 0.9821
# Epoch 331/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0743 - acc: 0.9643
# Epoch 332/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0994 - acc: 0.9643
# Epoch 333/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0964 - acc: 0.9643
# Epoch 334/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1354 - acc: 0.9643
# Epoch 335/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1579 - acc: 0.9821
# Epoch 336/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1343 - acc: 0.9643
# Epoch 337/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0737 - acc: 0.9643
# Epoch 338/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0746 - acc: 0.9464
# Epoch 339/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0659 - acc: 0.9821
# Epoch 340/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1967 - acc: 0.9286
# Epoch 341/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1073 - acc: 0.9643
# Epoch 342/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0485 - acc: 1.0000
# Epoch 343/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0776 - acc: 0.9821
# Epoch 344/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0783 - acc: 0.9464
# Epoch 345/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0787 - acc: 0.9821
# Epoch 346/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1289 - acc: 0.9643
# Epoch 347/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0724 - acc: 0.9821
# Epoch 348/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0760 - acc: 0.9643
# Epoch 349/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1091 - acc: 0.9821
# Epoch 350/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1488 - acc: 0.9643
# Epoch 351/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.1288 - acc: 0.9464
# Epoch 352/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0385 - acc: 0.9821
# Epoch 353/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0578 - acc: 0.9821
# Epoch 354/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0566 - acc: 0.9643
# Epoch 355/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1809 - acc: 0.9643
# Epoch 356/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1618 - acc: 0.9107
# Epoch 357/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0908 - acc: 0.9821
# Epoch 358/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1123 - acc: 0.9643
# Epoch 359/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0302 - acc: 1.0000
# Epoch 360/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0552 - acc: 0.9643
# Epoch 361/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0309 - acc: 0.9821
# Epoch 362/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1096 - acc: 0.9464
# Epoch 363/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.0357 - acc: 1.0000
# Epoch 364/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1028 - acc: 0.9643
# Epoch 365/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0740 - acc: 0.9643
# Epoch 366/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0917 - acc: 0.9643
# Epoch 367/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1187 - acc: 0.9464
# Epoch 368/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0595 - acc: 0.9821
# Epoch 369/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0565 - acc: 0.9821
# Epoch 370/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0397 - acc: 0.9821
# Epoch 371/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0915 - acc: 0.9821
# Epoch 372/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0674 - acc: 0.9821
# Epoch 373/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1250 - acc: 0.9643
# Epoch 374/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1268 - acc: 0.9643
# Epoch 375/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0744 - acc: 0.9643
# Epoch 376/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0779 - acc: 0.9643
# Epoch 377/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0862 - acc: 0.9643
# Epoch 378/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0995 - acc: 0.9643
# Epoch 379/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0733 - acc: 0.9643
# Epoch 380/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1264 - acc: 0.9464
# Epoch 381/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0804 - acc: 0.9643
# Epoch 382/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0757 - acc: 0.9643
# Epoch 383/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0769 - acc: 0.9821
# Epoch 384/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0716 - acc: 0.9643
# Epoch 385/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0833 - acc: 0.9643
# Epoch 386/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0884 - acc: 0.9464
# Epoch 387/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0853 - acc: 0.9821
# Epoch 388/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0438 - acc: 0.9821
# Epoch 389/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1220 - acc: 0.9464
# Epoch 390/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1416 - acc: 0.9286
# Epoch 391/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0549 - acc: 0.9821
# Epoch 392/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0890 - acc: 0.9643
# Epoch 393/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0583 - acc: 0.9821
# Epoch 394/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0324 - acc: 1.0000
# Epoch 395/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0867 - acc: 0.9643
# Epoch 396/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0963 - acc: 0.9643
# Epoch 397/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1207 - acc: 0.9107
# Epoch 398/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.2514 - acc: 0.9107
# Epoch 399/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.3136 - acc: 0.8750
# Epoch 400/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1285 - acc: 0.9286
# Epoch 401/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1421 - acc: 0.9643
# Epoch 402/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0282 - acc: 1.0000
# Epoch 403/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0724 - acc: 0.9643
# Epoch 404/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1700 - acc: 0.9464
# Epoch 405/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0741 - acc: 0.9643
# Epoch 406/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1104 - acc: 0.9286
# Epoch 407/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0899 - acc: 0.9643
# Epoch 408/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0889 - acc: 0.9821
# Epoch 409/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.1230 - acc: 0.9464
# Epoch 410/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0744 - acc: 0.9821
# Epoch 411/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1835 - acc: 0.9286
# Epoch 412/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1351 - acc: 0.9643
# Epoch 413/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.1129 - acc: 0.9643
# Epoch 414/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.1282 - acc: 0.9643
# Epoch 415/500
# 56/56 [==============================] - 0s 570us/sample - loss: 0.1073 - acc: 0.9464
# Epoch 416/500
# 56/56 [==============================] - 0s 481us/sample - loss: 0.0469 - acc: 0.9821
# Epoch 417/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1426 - acc: 0.9107
# Epoch 418/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0865 - acc: 0.9821
# Epoch 419/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1096 - acc: 0.9821
# Epoch 420/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1327 - acc: 0.9464
# Epoch 421/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0504 - acc: 1.0000
# Epoch 422/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1344 - acc: 0.9286
# Epoch 423/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0922 - acc: 0.9464
# Epoch 424/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1022 - acc: 0.9286
# Epoch 425/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0853 - acc: 0.9643
# Epoch 426/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0339 - acc: 0.9821
# Epoch 427/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0549 - acc: 0.9821
# Epoch 428/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1177 - acc: 0.9464
# Epoch 429/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0509 - acc: 1.0000
# Epoch 430/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0905 - acc: 0.9821
# Epoch 431/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1542 - acc: 0.9643
# Epoch 432/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0853 - acc: 0.9643
# Epoch 433/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1789 - acc: 0.8929
# Epoch 434/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0912 - acc: 0.9464
# Epoch 435/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0368 - acc: 0.9821
# Epoch 436/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0517 - acc: 0.9821
# Epoch 437/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0620 - acc: 0.9821
# Epoch 438/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1211 - acc: 0.9286
# Epoch 439/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.2490 - acc: 0.9286
# Epoch 440/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1131 - acc: 0.9286
# Epoch 441/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.2198 - acc: 0.9286
# Epoch 442/500
# 56/56 [==============================] - 0s 499us/sample - loss: 0.0345 - acc: 1.0000
# Epoch 443/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.1056 - acc: 0.9821
# Epoch 444/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.0877 - acc: 0.9821
# Epoch 445/500
# 56/56 [==============================] - 0s 552us/sample - loss: 0.0142 - acc: 1.0000
# Epoch 446/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.1232 - acc: 0.9286
# Epoch 447/500
# 56/56 [==============================] - 0s 427us/sample - loss: 0.0935 - acc: 0.9286
# Epoch 448/500
# 56/56 [==============================] - 0s 463us/sample - loss: 0.1182 - acc: 0.9643
# Epoch 449/500
# 56/56 [==============================] - 0s 445us/sample - loss: 0.0549 - acc: 0.9821
# Epoch 450/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.2392 - acc: 0.8929
# Epoch 451/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0621 - acc: 0.9821
# Epoch 452/500
# 56/56 [==============================] - 0s 481us/sample - loss: 0.0596 - acc: 0.9821
# Epoch 453/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.0918 - acc: 0.9643
# Epoch 454/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0658 - acc: 0.9643
# Epoch 455/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.1395 - acc: 0.9464
# Epoch 456/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0641 - acc: 0.9643
# Epoch 457/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0605 - acc: 0.9643
# Epoch 458/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0328 - acc: 0.9821
# Epoch 459/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0905 - acc: 0.9464
# Epoch 460/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0764 - acc: 0.9643
# Epoch 461/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1143 - acc: 0.9821
# Epoch 462/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0435 - acc: 0.9821
# Epoch 463/500
# 56/56 [==============================] - 0s 392us/sample - loss: 0.0942 - acc: 0.9464
# Epoch 464/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.1037 - acc: 0.9821
# Epoch 465/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1617 - acc: 0.9107
# Epoch 466/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0574 - acc: 0.9643
# Epoch 467/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0742 - acc: 0.9643
# Epoch 468/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0786 - acc: 0.9821
# Epoch 469/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0663 - acc: 0.9821
# Epoch 470/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0497 - acc: 0.9821
# Epoch 471/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0419 - acc: 0.9821
# Epoch 472/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0558 - acc: 0.9643
# Epoch 473/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0422 - acc: 0.9821
# Epoch 474/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0874 - acc: 0.9821
# Epoch 475/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0674 - acc: 0.9643
# Epoch 476/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0822 - acc: 0.9643
# Epoch 477/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.1364 - acc: 0.9643
# Epoch 478/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0841 - acc: 0.9643
# Epoch 479/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1400 - acc: 0.9464
# Epoch 480/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0245 - acc: 0.9821
# Epoch 481/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.1049 - acc: 0.9464
# Epoch 482/500
# 56/56 [==============================] - 0s 410us/sample - loss: 0.0853 - acc: 0.9464
# Epoch 483/500
# 56/56 [==============================] - 0s 374us/sample - loss: 0.0799 - acc: 0.9643
# Epoch 484/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0393 - acc: 0.9821
# Epoch 485/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0872 - acc: 0.9464
# Epoch 486/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0438 - acc: 1.0000
# Epoch 487/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0368 - acc: 1.0000
# Epoch 488/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0882 - acc: 0.9643
# Epoch 489/500
# 56/56 [==============================] - 0s 356us/sample - loss: 0.0867 - acc: 0.9464
# Epoch 490/500
# 56/56 [==============================] - 0s 339us/sample - loss: 0.0698 - acc: 0.9821
# Epoch 491/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0540 - acc: 0.9643
# Epoch 492/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0609 - acc: 0.9643
# Epoch 493/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0716 - acc: 0.9821
# Epoch 494/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1205 - acc: 0.9464
# Epoch 495/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.1127 - acc: 0.9821
# Epoch 496/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0640 - acc: 0.9643
# Epoch 497/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0442 - acc: 0.9821
# Epoch 498/500
# 56/56 [==============================] - 0s 321us/sample - loss: 0.0867 - acc: 0.9643
# Epoch 499/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0724 - acc: 0.9643
# Epoch 500/500
# 56/56 [==============================] - 0s 338us/sample - loss: 0.0586 - acc: 0.9643

# %% [markdown]
# ## Preprocess User Query

# %%
# performs preprocessing on inputted text (lower casing and lemmatization)
def preprocess_input(text):
    text_token = nltk.word_tokenize(text)
    text_token = [lem.lemmatize(word.lower()) for word in text_token]
    return text_token

# coverts preprocessed text to a matrix form 
def bow_en(text_token):
    bag = []
    for word in words_en:
        if word in text_token:
            bag.append(1)
        else:
            bag.append(0)
    return bag

def bow_es(text_token):
    bag = []
    for word in words_es:
        if word in text_token:
            bag.append(1)
        else:
            bag.append(0)
    return bag

# inputs user query in matrix form and returns a predicted label 
def predict_label_en(bow_en):
    prediction = model_en.predict(np.array(bow_en).reshape((1, len(words_en))))
    max_value = np.max(prediction)
    if max_value > 0.9:
        predict_label = labels_en[np.argmax(prediction)]
    else:
        predict_label = 'NA'
    return predict_label

def predict_label_es(bow_es):
    prediction = model_es.predict(np.array(bow_es).reshape((1, len(words_es))))
    max_value = np.max(prediction)
    if max_value > 0.9:
        predict_label = labels_es[np.argmax(prediction)]
    else:
        predict_label = 'NA'
    return predict_label

# %% [markdown]
# ## Response Generation

# %% [markdown]
# ### English Responses

# %%
# inputs the user intent and returns the appropriate response
def generate_response_en(query_intent, user):
    
    
    responses_en = { 
        'cancel' : "Ok, it's cancelled. Once you're ready, please type *`daily`* to fill out your follow-up reports.",

        'chicken' : "Here comes Arthur!\n\n*[Launch Rubber Chicken]({{{url}}})* 🐔\n\n_Pro tip: you can change the last part of Arthur's URL in your browser in order to create a unique room.",

        'daily' :  "No response",
            
        'dailystatus' : "No response",
            
        'dashboard' :"Ok, please *[follow this link]({{{url}}})* to access the web dashboard.",

        'datetime' :  "The time information for your user is:",
            
        'disable' : "Ok, it's done. You have disconnected and disabled all private messaging between you and me.\nYou can still use the [web application]({{{url}}}).\n\nIf you want to talk to me again, just type *`enable`*",


        'enable' : ["It seems that you had enabled me previously, I'm ready to help you.\nPlease type *`help`* to know more about how I can help you.",
                    
                    "Hey! Welcome back, I'm ready to help you.\nYou can *[login into the web application]({{{url}}})* to check your settings."],
            
        'extras' :"Hey, your wish is my command, and these are the extra commands",
            
        'feedback' : "Hey {}, it'd be great to get some feedback from you. If it's something important, I recommend you to visit our support center.".format(user.first_name),

        'hello' : "Hey {}! Have a great day and remember I'm so happy about being your friend.\nType *`help`* to learn more about me.".format(user.first_name),

        'help' : "Hey, your wish is my command, and these are my available commands:",

        'kudos' :  "kudos response: ",
        
        'news' :  "Take a look at *[my blog](https://www.dailybot.co/blog/)* to read about tips, key learnings and other content that our team is sharing.",

        'report' : 'No response',
        
        'resetdaily' :"This command has been changed, please type *`help`* to see all current commands.",

        'settings' : "This is a quick overview of your settings. You can manage these settings on my *[Web Application]({{{url}}})*:",

        'skipdaily' :"no response",
        
        'snooze' : "Ok, I’ll remind you in *{{time}} minutes*",

        'textformat' : "Hi there! The following is a list of the different formats I support.\nYou can also see this *[support article](https://www.dailybot.com)* to know more about how to build responses with these formats.",

        'thanks' : ["Oh, don't you even mention it. I'm always happy to help.",
                                "It's always my pleasure.",
                                "You are so very welcome.",
                                "It's no trouble at all. 😊",
                                "Anytime! it's always my pleasure. 😊"],
       
        'timezone' : "The time information for the typed timezone is:",

        'NA':  "Sorry for not understanding. Please type *`help`* for me to help you.",
        
        'meeting': "Set an appointment with whom?"
        
        
    }

    return responses_en[query_intent]

# %% [markdown]
# ### Spanish Responses

# %%
    
# inputs the user intent and returns the appropriate response
def generate_response_es(query_intent, user):
    
    responses_es = { 
        'cancel' : "Ok, has cancelado tu seguimiento diario. Por favor escribe *`daily`* para empezar cuando desees.",
    
        'chicken' : "¡Aquí viene Arthur!\n\n[Abrir Rubber Chicken]({{{url}}}) 🐔\n\n_Pro tip: puedes cambiar la última parte de la URL de Arthur en tu navegador y así tendrás una sala única._",

        'daily' :  "No hay respuesta",
        
        'dailystatus' :  "No hay respuesta",
        
        'dashboard' : "Ok, *[abre este enlace]({{{url}}})* para abrir la web y dashboard.",

        'datetime' : "La información horaria de tu usuario es:",

        'disable' : "Listo, está hecho. Has desconectado y deshabilitado todos los mensajes privados entre tu y yo.\nPor cierto, puedes seguir utilizando mi [aplicación web]({{{url}}}).\n\nSi deseas volver a hablar conmigo simplemente escribe *`enable`*.",

        'enable' : "Parece que ya me habías habilitado previamente, estoy listo para ayudarte.\nPor favor, escribe *`help`* para saber más sobre cómo puedo ayudarte.",
                    # 8. "¡Hola! Bienvenido de nuevo, estoy listo para ayudarte.\nPor favor inicia sesión en mi *[aplicación web]({{{url}}})* para confirmar su configuración."
        
        'extras' : "Hola, puedes usar estos comandos extras para interactuar conmigo:",

        
        'feedback' : "Hola {}!, Sería grandióso recibir tu feedback. Si es algo importante, Te recomiendo visitar nuestro centro de soporte.".format(user.first_name),

        
        'hello' :  "¡Hola {}! Ten un excelente día y recuerda que estoy muy feliz de ser tu amigo.\nEscribe *`help`* para aprender más sobre mí.".format(user.first_name),

        
        'help' : "Hola, puedes usar estos comandos para interactuar conmigo:",
        
        'kudos' :"kudos response: ",
        
        'news' : "Echa un vistazo a *[mi blog](https://www.dailybot.com/blog/)* (en inglés) para leer sobre trucos, aprendizajes y otro contenido que comparte nuestro equipo.",

        
        'report' : "No hay respuesta",
        
        'resetdaily' : "Este comando ha cambiado, por favor escribe *`help`* para ver todos los comandos actuales.",

        'settings' : "Este es un resúmen de tu configuración. Puedes gestionar la configuración en mi *[aplicación web]({{{url}}})*:",

        'skipdaily' : "No hay respuesta",
        
        'snooze' : "Ok, te recordaré en *{{time}} minutos*.",

        'textformat' : "Hola! La siguiente es una lista de los diferentes formatos que soporto.\nPuedes verlo aquí *[artículo de apoyo](https://www.dailybot.com)* para conocer más acerca de como construir respuestas con estos formatos.",

        'thanks' : ["¡Con muuucho gusto!",
                                 "Siempre es un placer.",
                                 "Estoy para ayudarte.",
                                 "A ti por tu tiempo. 😊",
                                 "¡Cuando me necesites! siempre es un placer. 😊"],
    
        'timezone' :  "La información de la zona horaria introducida es:",

        'NA': "Lo siento por no entender. Por favor escribe *`help`* para ayudarte.",
        
        'meeting': "Set an appointment with whom?"
    }

    return responses_es[query_intent]

# %% [markdown]
# ## Saving unidentified Queries

# %%
# Create list of queries with no response
try:
    no_intent_queries = open("no_intent_queries.txt", "x")
except:
    pass

# %% [markdown]
# ## Load User Object

# %%
from imp import reload
import UserObjects

reload(UserObjects)

User = UserObjects.User
Settings = UserObjects.Settings
DailyReport = UserObjects.DailyReport
Appointment = UserObjects.Appointment
vars(Appointment)
# Out:
# mappingproxy({'__module__': 'UserObjects',
#               '__init__': <function UserObjects.Appointment.__init__(self, member, time)>,
#               'show_appointments': <function UserObjects.Appointment.show_appointments(self)>,
#               '__dict__': <attribute '__dict__' of 'Appointment' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Appointment' objects>,
#               '__doc__': None})

# %%
aashish_user = User(first_name="Aashish", last_name="Nair", language="English")
aashish_settings = Settings(is_enabled=True, given_feedback=False)
aashish_daily_report = DailyReport(is_completed=True)
aashish_meeting = Appointment(member=None, time=None)

aashish_user.settings = aashish_settings
aashish_user.daily_report = aashish_daily_report
aashish_user.appointment = aashish_meeting

# %%
type(print(vars(aashish_meeting)))
# Out:
# {'member': None, 'time': None}
# NoneType

# %% [markdown]
# # Chatbot

# %%
def chatbot(user):
    
    
    queries_list = ""
    
    print('Insert command here (type "quit" to stop chatbot)\n')

    while 1 >0:

        input_text = input()
        if input_text=='quit':
            break
        if len(input_text) < 3:
            while len(input_text) <3:
                input_text = input_text + " "

        if user.language =='English':

            spell = Speller(lang='en')
            if input_text not in intents_en:
                input_text = spell(input_text)
            prediction_en = predict_label_en(np.array(bow_en(preprocess_input(input_text))))

            # thanks intent
            if prediction_en == 'thanks':
                response_en = random.choice(generate_response_en(prediction_en, user))
                print(response_en)
                print(' ')

            # enable intent
            elif prediction_en == 'enable':
                response_en = generate_response_en(prediction_en, user)
                if user.settings.is_enabled: 
                    response_en = response_en[0]
                else:
                    user.settings.enable()
                    response_en = response_en[1]
                print(response_en)
                print(' ')

            # disable intent                   
            elif prediction_en == 'disable':
                user.settings.disable()
                response_en = generate_response_en(prediction_en, user)
                print(response_en)
                print(' ')

            elif prediction_en == 'skipdaily':
                response_en = generate_response_en(prediction_en, user)
                user.daily_report.skip_daily()
                print(response_en)
                print(' ')

            elif prediction_en == 'cancel':
                response_en = generate_response_en(prediction_en, user)
                user.daily_report.cancel()
                print(response_en)
                print(' ')

            elif prediction_en == 'meeting':
                response_en = generate_response_en(prediction_en, user)
                print(response_en)
                print(' ')
                appointment_with = input()
                print('Which day?')
                time = ""
                appointment_day = input()
                time = time + appointment_day + " "
                print('What time?')
                appointment_time = input()
                time = time + appointment_time
                
                date = dateparser.parse(time)
                user.appointment = Appointment(member=appointment_with, time=date)
                
                print('Appointment scheduled at {} on {} with the following people: {}'.format(appointment_day, appointment_time, appointment_with))
                print(' ')
                
            elif prediction_en == 'meeting status':
                if vars(user.appointment)['time'] is None:
                    print('You have no meetings')
                else:
                    aashish_user.appointment.show_appointments()
                
            else:
                response_en = generate_response_en(prediction_en, user)
                print(response_en)
                print(' ')
            if prediction_en == 'NA':
                queries_list = queries_list + input_text+ '\n'

        elif user.language == 'Spanish':
            spell = Speller(lang='es')
            input_text = spell(input_text)
            prediction_es = predict_label_es(np.array(bow_es(preprocess_input(input_text))))
            if prediction_es == 'thanks':
                response_es = random.choice(generate_response_es(prediction_es, user))
            else:
                response_es = generate_response_es(prediction_es, user)
            print(response_es)
            print(' ')
            if prediction == 'NA':
                queries_list = queries_list + input_text+ '\n'

# %%
chatbot(aashish_user)
# Out:
# Insert command here (type "quit" to stop chatbot)
#
# hi
# Hey Aashish! Have a great day and remember I'm so happy about being your friend.
# Type *`help`* to learn more about me.
#
# meeting
# Set an appointment with whom?
#
# Sergio
# Which day?
# tomorrow
# What time?
# 1:00 pm
# Appointment scheduled at tomorrow on 1:00 pm with the following people: Sergio
#
# show meetings
# Appointments:
#
# At 2021-03-13 13:00:00 with Sergio
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-d25574d52bef> in <module>
# ----> 1 chatbot(aashish_user)
#
# <ipython-input-211-e68330d4724b> in chatbot(user)
#       8     while 1 >0:
#       9
# ---> 10         input_text = input()
#      11         if input_text=='quit':
#      12             break
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Add "NA" Queries to .txt File

# %%
aashish_user.appointment.show_appointments()
# Out:
# Appointments:
#
# At 2021-03-11 22:00:00 with Sergio

# %%
c[0]

# %%
generate_response_en('meeting', aashish_user)

# %%
text = 'Meet me on 09/2020 please James'
nlp = spacy.load('en_core_web_sm')

text_nlp = nlp(text)

for entities in text_nlp.ents:
    print(entities.label_," ---> ",entities.text)
# Out:
# PERSON  --->  James

# %%
date = dateparser.parse('March 21st 4:30 pm')
print(date)
# Out:
# 2021-03-21 16:30:00
